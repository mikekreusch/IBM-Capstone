# %% [markdown]
# # <CENTER>CAPSTONE PROJECT | SALES TERRITORY SCORE FOR TORONTO NEIGHBORHOODS</CENTER>

# %% [markdown]
# # INTRODUCTION

# %% [markdown]
# <b>PROBLEM</b>
#
# In order to properly allocate salespeople into sales territories, characteristics of the territory in question must be evaluated. My Capstone project will identify neighborhoods in Toronto as potential sales territories. The client is an advertising sales company ("Cafn8") that employs independent subcontractors as sales agents. The product is coffee shop display advertising, specifically:
#
# •	Branded packaging (heat sleeves, cups, bags, single-portion sweetener, etc.)<br>
# •	In-shop digital kiosks<br>
# •	Coupons integrated into transaction receipts (print or digital)
#
# Neighborhood rankings will be based on a proprietary scoring algorithm (“Prosval”) that assigns points to businesses in a neighborhood by venue type, then sums those points into a territory score for each neighborhood ("Terriscore"). Neighborhoods with a large number of businesses are favorable, and certain types of businesses are more favorable compared to others, so a summation index should be robust. Cafn8 has asked for neighborhoods to be ranked based on their Terriscore, and for certain tables of information to be produced. <b>The goal of this project is to produce the information Cafn8 has requested.</b>
#
# <b>BACKGROUND</b>
#
# By definition, anyone in a given coffee shop is in that location. By extension, they are also in proximity to all of the surrounding businesses. Business operators interested in brand marketing to people who are actually near them can derive great value from doing so inside a coffee shop in their neighborhood. Successful coffee shops enjoy relatively high traffic counts, and many of their customers are “regulars” from the neighborhood who visit daily, some of them staying for long periods of time. This kind of repeat exposure to display advertising is a phenomenal brand building opportunity.
#
# Brand building is an essential but hard to attribute component of any marketing program. Resources committed to brand marketing do not directly convert into observable sales the same way coupon redemptions or online click-throughs do, for example. Brand marketing intends to create a familiarity and image advantage with potential customers when they actively seek out your product or service. This typically involves large scale, expensive, mass media type programs that are inappropriate for small, locally focused businesses.
#
# Leveraging the notion of a coffee shop as an essential “third place” in a community (“The Third Place: Our Commitment, Renewed” - https://starbuckschannel.com/thethirdplace/) within which to advertise a local business is not entirely new. The same idea was executed in supermarkets with great success by TV Fanfare Publications starting in the 1950’s (“TV Fanfare Publications : Making Big Business From Small Ads” - http://articles.latimes.com/1985-02-21/business/fi-773_1_guides ). The essential driver of value in such a marketing program is to offer local businesses access to nearby locations that are frequently visited by large proportions of their customer base. This kind of targeted, appropriate-scale brand marketing has a track record of success that can be expected to repeat, because coffee shop owners work hard to establish and maintain a ubiquitous presence within a community.
#
# Cafn8 plans to use the final product from this project to assign its subcontractor sales agents to neighborhoods in Toronto. Those sales agents are responsible for entering an agreement with a coffee shop to allow display advertising inside their establishment. The incentive for the coffee shop is free supplies (Heat sleeves, cups, napkins, single serving sweetener, etc. Wi-Fi if there is a digital kiosk placed. Access to customer data if ecoupons are sent with digital receipts.). Coffee shops have some discretion over what venue types they will allow to advertise, but as a rule they agree to accept branded advertising from anyone Cafn8 has approved. After entering an agreement with a coffee shop, the sales agent must find local businesses to advertise there. Once a particular coffee shop has signed up and the advertising capacity reaches a necessary minimum level, the sales agent is eligible to be paid and they can move onto the next neighborhood to repeat the process.

# %% [markdown]
# # DATA

# %% [markdown]
# We will be using the following data:
#
# •	A listing of neighborhoods by Postal Code obtained from Wikipedia (https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M)<br>
# •	Latitude/Longitude data provided via Cognitive Class (https://cocl.us/Geospatial_data)<br>
# •	Toronto city data accessible through the FourSquare API<br>
# •	Terrivalue data for each type of business provided by Cafn8<br>
#
# This data will produce the following deliverables.
#
# •	A list of coffee shops in Toronto, by neighborhood (with Terriscore)<br>
# •	A list of businesses, by neighborhood (with Prosval and Terriscore)<br>
# •	A ranking of all neighborhoods based on their Terriscore<br>
#
#
# Neighborhoods will become sales territories. Terriscore is calculated from a proprietary algorithm that assigns a Prosval to each type of business. All business types are ranked by Cafn8 as follows:
#
# •	2 - Most desirable prospects offering higher success rates for display advertising sales<br>
# •	1 - Neutral prospects that are hit or miss and not priority to pursue<br>
# •	0 - Least desirable prospects to call or prohibited businesses<br>
#
# Businesses within a neighborhood are scored via Prosval and summed into that neighborhood’s Terriscore. Once all neighborhoods have been scored, the list will be ranked from highest to lowest based on Terriscore. <b>The ranked list will be the focus final product.</b>

# %% [markdown]
# # METHODOLOGY

# %% [markdown]
# <b>We will begin by importing libraries and resources that we will need for the purposes of this project

# %%
import numpy as np

import pandas as pd 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', 1000)

import json 

# !conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests 
from pandas.io.json import json_normalize 

import matplotlib.cm as cm
import matplotlib.colors as colors

from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes

from bs4 import BeautifulSoup as BS
import urllib.request

import random

print('!!!!!!! Libraries imported !!!!!!!')
# Out:
# Collecting package metadata: ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Collecting package metadata: ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# !!!!!!! Libraries imported !!!!!!!

# %% [markdown]
# <b>We will import a table of business type Prosvals from a .csv file provided by Cafn8

# %% [markdown]
# The first thing we will present is a table that defines bunsiness type values ("Prosval") for the <b>355 business types</b> in our dataset. This table was completed by Cafn8 after we identified 355 FourSquare API business types in the Toronto neighborhood data. Cafn8 has explained that venue values have been assigned by senior sales staff based on their collective experience selling advertising to small local businesses.
#
# NOTE: Some business types or specific businesses may be prohibited from buying advertising from Cafn8 (direct coffee shop competitors, certain "sin" businesses, prior bad credits, etc.). This version of the table includes no such business type prohibitions. On a coffee shop by coffee shop basis additional venue types are subject to prohibition as well. Coffee shops cannot accept advertising from any business Cafn8 prohibits even if they are willing to do so.

# %%
prosval = pd.read_csv('C:\\Users\HP\Desktop\COURSERA\IBM Data Science\CAPSTONE\PROSVAL.csv', encoding = "ISO-8859-1")

print(prosval.shape)
prosval
# Out:
# (355, 3)
#                                      CATEGORY PROHIBITED  PROSVAL
# 0                           Accessories Store         No        2
# 1                              Adult Boutique         No        0
# 2                           Afghan Restaurant         No        1
# 3                          African Restaurant         No        1
# 4                                     Airport         No        0
# 5                          Airport Food Court         No        0
# 6                                Airport Gate         No        0
# 7                              Airport Lounge         No        0
# 8                             Airport Service         No        0
# 9                            Airport Terminal         No        0
# 10                        American Restaurant         No        1
# 11                               Amphitheater         No        0
# 12                             Animal Shelter         No        1
# 13                               Antique Shop         No        2
# 14                                   Aquarium         No        1
# 15                           Arepa Restaurant         No        1
# 16                                Art Gallery         No        0
# 17                                 Art Museum         No        1
# 18                        Arts & Crafts Store         No        2
# 19                           Asian Restaurant         No        1
# 20                         Athletics & Sports         No        0
# 21                            Auto Dealership         No        2
# 22                                Auto Garage         No        2
# 23                              Auto Workshop         No        2
# 24                            Automotive Shop         No        2
# 25                                 Baby Store         No        2
# 26                            Badminton Court         No        1
# 27                                 Bagel Shop         No        0
# 28                                     Bakery         No        0
# 29                                       Bank         No        1
# 30                                        Bar         No        1
# 31                             Baseball Field         No        0
# 32                           Baseball Stadium         No        0
# 33                           Basketball Court         No        0
# 34                         Basketball Stadium         No        0
# 35                                  BBQ Joint         No        0
# 36                                      Beach         No        0
# 37                                  Beach Bar         No        1
# 38                                   Beer Bar         No        1
# 39                                 Beer Store         No        2
# 40                         Belgian Restaurant         No        1
# 41                                  Bike Shop         No        2
# 42                                     Bistro         No        0
# 43                                 Board Shop         No        1
# 44                              Boat or Ferry         No        1
# 45                                  Bookstore         No        1
# 46                                   Boutique         No        2
# 47                              Bowling Alley         No        2
# 48                       Brazilian Restaurant         No        1
# 49                             Breakfast Spot         No        0
# 50                                    Brewery         No        1
# 51                                Bridal Shop         No        1
# 52                                     Bridge         No        0
# 53                            Bubble Tea Shop         No        0
# 54                                     Buffet         No        0
# 55                               Burger Joint         No        0
# 56                              Burrito Place         No        0
# 57                                   Bus Line         No        0
# 58                                Bus Station         No        0
# 59                                   Bus Stop         No        0
# 60                           Business Service         No        0
# 61                                    Butcher         No        2
# 62                                       Café         No        0
# 63                                  Cafeteria         No        1
# 64                  Cajun / Creole Restaurant         No        1
# 65                                Candy Store         No        2
# 66                       Cantonese Restaurant         No        1
# 67                       Caribbean Restaurant         No        1
# 68                                     Castle         No        1
# 69                                   Cemetery         No        1
# 70                      Check Cashing Service         No        2
# 71                                Cheese Shop         No        2
# 72                         Chinese Restaurant         No        1
# 73                               Chiropractor         No        2
# 74                             Chocolate Shop         No        2
# 75                                     Church         No        1
# 76                               Churrascaria         No        1
# 77                               Climbing Gym         No        2
# 78                             Clothing Store         No        1
# 79                               Cocktail Bar         No        0
# 80                                Coffee Shop         No        0
# 81                      College Arts Building         No        0
# 82                         College Auditorium         No        0
# 83                                College Gym         No        0
# 84                               College Quad         No        0
# 85                         College Rec Center         No        0
# 86                            College Stadium         No        0
# 87                            College Theater         No        1
# 88                                Comedy Club         No        1
# 89                    Comfort Food Restaurant         No        1
# 90                                 Comic Shop         No        2
# 91                           Community Center         No        1
# 92                               Concert Hall         No        0
# 93                 Construction & Landscaping         No        1
# 94                          Convenience Store         No        0
# 95                             Cosmetics Shop         No        2
# 96                            Coworking Space         No        0
# 97                                   Creperie         No        0
# 98                           Cuban Restaurant         No        1
# 99                               Cupcake Shop         No        2
# 100                               Curling Ice         No        1
# 101                              Dance Studio         No        2
# 102                             Deli / Bodega         No        1
# 103                          Department Store         No        1
# 104                             Design Studio         No        1
# 105                              Dessert Shop         No        2
# 106                        Dim Sum Restaurant         No        1
# 107                                     Diner         No        0
# 108                            Discount Store         No        1
# 109                                  Dive Bar         No        1
# 110                                   Dog Run         No        0
# 111                          Doner Restaurant         No        1
# 112                                Donut Shop         No        0
# 113                                 Drugstore         No        2
# 114                       Dumpling Restaurant         No        1
# 115               Eastern European Restaurant         No        1
# 116                         Electronics Store         No        1
# 117                       Empanada Restaurant         No        1
# 118                      Ethiopian Restaurant         No        1
# 119                               Event Space         No        0
# 120                                   Exhibit         No        1
# 121                        Falafel Restaurant         No        1
# 122                                      Farm         No        1
# 123                            Farmers Market         No        0
# 124                      Fast Food Restaurant         No        1
# 125                                     Field         No        0
# 126                       Filipino Restaurant         No        1
# 127                           Fireworks Store         No        1
# 128                         Fish & Chips Shop         No        0
# 129                               Fish Market         No        1
# 130                               Flea Market         No        1
# 131                               Flower Shop         No        2
# 132                                      Food         No        0
# 133                         Food & Drink Shop         No        0
# 134                                Food Court         No        0
# 135                                Food Truck         No        0
# 136                                  Fountain         No        0
# 137                         French Restaurant         No        1
# 138                       Fried Chicken Joint         No        0
# 139                        Frozen Yogurt Shop         No        0
# 140                   Fruit & Vegetable Store         No        2
# 141                    Furniture / Home Store         No        1
# 142                               Gaming Cafe         No        0
# 143                                    Garden         No        0
# 144                             Garden Center         No        2
# 145                               Gas Station         No        1
# 146                                 Gastropub         No        0
# 147                                   Gay Bar         No        1
# 148                     General Entertainment         No        1
# 149                            General Travel         No        1
# 150                         German Restaurant         No        1
# 151                                 Gift Shop         No        1
# 152                    Gluten-free Restaurant         No        1
# 153                               Golf Course         No        0
# 154                              Gourmet Shop         No        2
# 155                          Greek Restaurant         No        1
# 156                             Grocery Store         No        0
# 157                                       Gym         No        2
# 158                      Gym / Fitness Center         No        2
# 159                                  Gym Pool         No        1
# 160                          Hakka Restaurant         No        1
# 161                           Harbor / Marina         No        0
# 162                            Hardware Store         No        2
# 163                       Hawaiian Restaurant         No        1
# 164                   Health & Beauty Service         No        2
# 165                         Health Food Store         No        1
# 166                             Historic Site         No        1
# 167                            History Museum         No        1
# 168                                Hobby Shop         No        2
# 169                              Hockey Arena         No        0
# 170                              Home Service         No        0
# 171                      Hong Kong Restaurant         No        1
# 172                                Hookah Bar         No        0
# 173                                  Hospital         No        0
# 174                                    Hostel         No        1
# 175                             Hot Dog Joint         No        1
# 176                                     Hotel         No        1
# 177                                 Hotel Bar         No        1
# 178                         Hotpot Restaurant         No        1
# 179                       Housing Development         No        1
# 180                            Ice Cream Shop         No        0
# 181                 Indian Chinese Restaurant         No        1
# 182                         Indian Restaurant         No        1
# 183                       Indie Movie Theater         No        2
# 184                             Indie Theater         No        2
# 185                     Indonesian Restaurant         No        1
# 186                              Intersection         No        0
# 187                                 Irish Pub         No        1
# 188                        Italian Restaurant         No        1
# 189                       Japanese Restaurant         No        1
# 190                                 Jazz Club         No        1
# 191                             Jewelry Store         No        2
# 192                         Jewish Restaurant         No        1
# 193                                 Juice Bar         No        0
# 194                               Karaoke Bar         No        1
# 195                      Kitchen Supply Store         No        2
# 196                         Korean Restaurant         No        1
# 197                                      Lake         No        0
# 198                 Latin American Restaurant         No        1
# 199                           Laundry Service         No        2
# 200                        Light Rail Station         No        0
# 201                            Lighting Store         No        2
# 202                            Lingerie Store         No        1
# 203                              Liquor Store         No        1
# 204                                    Lounge         No        0
# 205                             Luggage Store         No        2
# 206                        Mac & Cheese Joint         No        0
# 207                          Malay Restaurant         No        1
# 208                                    Market         No        0
# 209                         Martial Arts Dojo         No        2
# 210                            Massage Studio         No        2
# 211                            Mattress Store         No        2
# 212                            Medical Center         No        2
# 213                  Mediterranean Restaurant         No        1
# 214                               Men's Store         No        2
# 215                             Metro Station         No        0
# 216                        Mexican Restaurant         No        1
# 217                 Middle Eastern Restaurant         No        1
# 218                        Miscellaneous Shop         No        0
# 219                         Mobile Phone Shop         No        2
# 220                Modern European Restaurant         No        1
# 221           Molecular Gastronomy Restaurant         No        1
# 222                       Monument / Landmark         No        0
# 223                       Moroccan Restaurant         No        1
# 224                                     Motel         No        1
# 225                           Motorcycle Shop         No        2
# 226                             Movie Theater         No        2
# 227                             Moving Target         No        0
# 228                                    Museum         No        1
# 229                              Music School         No        2
# 230                               Music Store         No        2
# 231                               Music Venue         No        2
# 232                                Nail Salon         No        2
# 233                              Neighborhood         No        0
# 234                   New American Restaurant         No        1
# 235                                 Nightclub         No        2
# 236                              Noodle House         No        0
# 237                                    Office         No        0
# 238                               Opera House         No        0
# 239                              Optical Shop         No        2
# 240                           Organic Grocery         No        2
# 241                      Other Great Outdoors         No        0
# 242                         Other Repair Shop         No        2
# 243                         Outdoor Sculpture         No        0
# 244                      Pakistani Restaurant         No        1
# 245             Paper / Office Supplies Store         No        1
# 246                                      Park         No        0
# 247                               Pastry Shop         No        1
# 248                     Performing Arts Venue         No        2
# 249                        Persian Restaurant         No        1
# 250                                 Pet Store         No        2
# 251                                  Pharmacy         No        2
# 252                           Photography Lab         No        1
# 253                                 Piano Bar         No        0
# 254                                Pide Place         No        1
# 255                                  Pie Shop         No        1
# 256                            Pilates Studio         No        1
# 257                               Pizza Place         No        0
# 258                                Playground         No        0
# 259                                     Plaza         No        0
# 260                                Poke Place         No        0
# 261                                      Pool         No        0
# 262                                 Pool Hall         No        1
# 263                     Portuguese Restaurant         No        1
# 264                             Poutine Place         No        0
# 265                                Print Shop         No        1
# 266                                       Pub         No        0
# 267                          Ramen Restaurant         No        1
# 268                               Record Shop         No        2
# 269                          Recording Studio         No        1
# 270                         Recreation Center         No        1
# 271                       Rental Car Location         No        1
# 272                            Rental Service         No        1
# 273  Residential Building (Apartment / Condo)         No        1
# 274                                Restaurant         No        1
# 275                                     River         No        0
# 276                                      Road         No        0
# 277                        Rock Climbing Spot         No        0
# 278                                 Rock Club         No        1
# 279                                  Sake Bar         No        0
# 280                               Salad Place         No        0
# 281                        Salon / Barbershop         No        2
# 282                            Sandwich Place         No        0
# 283                            Scenic Lookout         No        0
# 284                                    School         No        2
# 285                          Sculpture Garden         No        0
# 286                        Seafood Restaurant         No        1
# 287                       Shanghai Restaurant         No        1
# 288                                Shoe Store         No        1
# 289                            Shop & Service         No        1
# 290                             Shopping Mall         No        0
# 291                            Shopping Plaza         No        0
# 292                                Skate Park         No        0
# 293                              Skating Rink         No        1
# 294                                  Ski Area         No        1
# 295                                Ski Chalet         No        1
# 296                                Smoke Shop         No        2
# 297                             Smoothie Shop         No        0
# 298                               Snack Place         No        0
# 299                              Soccer Field         No        0
# 300                            Soccer Stadium         No        1
# 301                               Social Club         No        1
# 302                                Soup Place         No        0
# 303                 South American Restaurant         No        1
# 304           Southern / Soul Food Restaurant         No        1
# 305                             Souvlaki Shop         No        1
# 306                                       Spa         No        2
# 307                        Spanish Restaurant         No        1
# 308                                 Speakeasy         No        0
# 309                       Sporting Goods Shop         No        1
# 310                                Sports Bar         No        0
# 311                               Sports Club         No        1
# 312                     Sri Lankan Restaurant         No        1
# 313                                   Stadium         No        0
# 314                          Stationery Store         No        2
# 315                                Steakhouse         No        0
# 316                          Storage Facility         No        1
# 317                                Street Art         No        0
# 318                                Strip Club         No        1
# 319                               Supermarket         No        2
# 320                           Supplement Shop         No        1
# 321                          Sushi Restaurant         No        1
# 322                               Swim School         No        2
# 323                                Taco Place         No        1
# 324                               Tailor Shop         No        2
# 325                      Taiwanese Restaurant         No        1
# 326                             Tanning Salon         No        2
# 327                          Tapas Restaurant         No        1
# 328                                  Tea Room         No        1
# 329                              Tech Startup         No        0
# 330                              Tennis Court         No        0
# 331                           Thai Restaurant         No        1
# 332                                   Theater         No        1
# 333                    Thrift / Vintage Store         No        1
# 334                        Tibetan Restaurant         No        1
# 335                          Toy / Game Store         No        1
# 336                                     Track         No        1
# 337                                     Trail         No        0
# 338                             Train Station         No        0
# 339                                      Tree         No        0
# 340                                    Tunnel         No        0
# 341                        Turkish Restaurant         No        1
# 342                                University         No        2
# 343             Vegetarian / Vegan Restaurant         No        1
# 344                          Video Game Store         No        1
# 345                               Video Store         No        1
# 346                     Vietnamese Restaurant         No        1
# 347                           Warehouse Store         No        1
# 348                                Whisky Bar         No        1
# 349                                  Wine Bar         No        1
# 350                                 Wine Shop         No        1
# 351                               Wings Joint         No        1
# 352                             Women's Store         No        1
# 353                               Yoga Studio         No        1
# 354                                       Zoo         No        0

# %% [markdown]
# The following steps convert the <b>Toronto Wikipedia postal codes table</b> into a dataframe.

# %%
res = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")
soup = BS(res.content,'lxml')
table = soup.find_all('table')[0] 
df = pd.read_html(str(table))[0]
postcode = df[0].tolist()
borough = df[1].tolist()
neigh = df[2].tolist()

print("Rows, columns in df", df.shape)
df.head()
# Out:
# Rows, columns in df (290, 3)
#           0             1                 2
# 0  Postcode       Borough     Neighbourhood
# 1       M1A  Not assigned      Not assigned
# 2       M2A  Not assigned      Not assigned
# 3       M3A    North York         Parkwoods
# 4       M4A    North York  Victoria Village

# %% [markdown]
# Clean up the Toronto postal codes dataframe

# %%
df = df.drop(0)

df = df.drop(df[df[1] == "Not assigned"].index)

df[2] = df[2].replace("Not assigned", df[1])

df = pd.DataFrame({0:df[0],1:df[1],2:df[2]})

df = df.groupby([0,1])[2].apply(lambda tags : ', '.join(tags)).reset_index()

df = df.rename(columns = {0:"PostalCode", 1:"Borough", 2:"Neighbourhood"})

print("Rows, columns in df", df.shape)
df.head()
# Out:
# Rows, columns in df (103, 3)
#   PostalCode      Borough                           Neighbourhood
# 0        M1B  Scarborough                          Rouge, Malvern
# 1        M1C  Scarborough  Highland Creek, Rouge Hill, Port Union
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill
# 3        M1G  Scarborough                                  Woburn
# 4        M1H  Scarborough                               Cedarbrae

# %% [markdown]
# Add latitude and longitude values to the dataframe from data provided by <b>Cognitive Class.</b>

# %%
dflatlng = pd.read_csv('https://cocl.us/Geospatial_data')

dftor = df.join(dflatlng)

dftor = dftor.drop(['Postal Code'], axis=1).reset_index(drop=True)

dftor.to_csv('C:\\Users\HP\Desktop\COURSERA\IBM Data Science\CAPSTONE\dftor.csv', encoding='UTF-8')

print("Rows, columns in dftor", dftor.shape)
dftor.head()
# Out:
# Rows, columns in dftor (103, 5)
#   PostalCode      Borough                           Neighbourhood   Latitude  Longitude
# 0        M1B  Scarborough                          Rouge, Malvern  43.806686 -79.194353
# 1        M1C  Scarborough  Highland Creek, Rouge Hill, Port Union  43.784535 -79.160497
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill  43.763573 -79.188711
# 3        M1G  Scarborough                                  Woburn  43.770992 -79.216917
# 4        M1H  Scarborough                               Cedarbrae  43.773136 -79.239476

# %% [markdown]
# At this point we connect with the <b>FourSquare API.</b>

# %% [markdown]
# FourSquare requires a client ID and client Secret to access its data via the API. They also require that you state what version of the API you are using. We will load these values into variables for ease of use throughout the project.

# %%
CLIENT_ID = 'ZGU4DXB3ROK4GNWTUAMJCARJMMC3J120HKWIYMXM52KJPZED' # your Foursquare ID
CLIENT_SECRET = 'RXGSRIHMW1EE1E54XL4NRHFIPJELLQ3SLFFZGW4UEDJ0VZTU' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your FourSquare API credentails\n')
print('    CLIENT_ID:  ' + CLIENT_ID)
print('CLIENT_SECRET:  ' + CLIENT_SECRET)
print('      VERSION:  ' + VERSION)
# Out:
# Your FourSquare API credentails
#
#     CLIENT_ID:  ZGU4DXB3ROK4GNWTUAMJCARJMMC3J120HKWIYMXM52KJPZED
# CLIENT_SECRET:  RXGSRIHMW1EE1E54XL4NRHFIPJELLQ3SLFFZGW4UEDJ0VZTU
#       VERSION:  20180605

# %% [markdown]
# Now we compile a list of FourSquare URLs for the <b>103 neighborhoods in Toronto.</b> These URL addresses contain neighborhood data we will use to extract a list of all coffee shops in each neighborhood in Toronto, and eventually all other businesses in each neighborhood.

# %%
radius = 1000
LIMIT = 100

URLs = []

x = 0

while x < 103 :

    neigh_lat = dftor.loc[x, 'Latitude']
    neigh_long = dftor.loc[x, 'Longitude']

    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neigh_lat, 
    neigh_long, 
    radius,
    LIMIT)
    
    URLs.append(url)
    
    #print(x, url)
    
    x = x + 1

# %%
print("Confirmed:", len(URLs), "URL addresses created.")
# Out:
# Confirmed: 103 URL addresses created.

# %% [markdown]
# The next step is to retrieve each URL and extract data for Toronto coffee shops.

# %%
shops = pd.DataFrame() # Data issues may require me to append to my dataframe in chunks, so I define it outside that code.

# %%
x = 0

while x < 103 :

    shopsresults = requests.get(URLs[x]).json()

    def get_category_type(row):
        try:
            categories_list = row['categories']
        except:
            categories_list = row['venue.categories']
        
        if len(categories_list) == 0:
            return None
        else:
            return categories_list[0]['name']

    shopsvenues = shopsresults['response']['groups'][0]['items']
    
    nearby_shopsvenues = json_normalize(shopsvenues) # flatten JSON

    # filter columns
    filtered_columns = ['venue.name', 'venue.location.address', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
    nearby_shopsvenues = nearby_shopsvenues.loc[:, filtered_columns]

    # filter the category for each row
    nearby_shopsvenues['venue.categories'] = nearby_shopsvenues.apply(get_category_type, axis=1)

    # clean columns
    nearby_shopsvenues.columns = [col.split(".")[-1] for col in nearby_shopsvenues.columns]

    dfven = nearby_shopsvenues.loc[nearby_shopsvenues['categories'] == 'Coffee Shop']
    
    dfven = dfven.reset_index(drop=True)
    
    if not dfven.empty :
        
        shops = shops.append(dfven)
        #print(x, '!!!', dftor.iloc[x]['PostalCode'], dftor.iloc[x]['Neighbourhood'], dfven.shape)
        
    x = x + 1
    
    if x == 16 : x = x + 1 # One URL causes FourSquare to reject our data request. We are skipping this URL.

# %% [markdown]
# We have produced a data frame with <b>348 coffee shops in Toronto.</b> One URL (index = 16) causes an issue with FourSquare, because it contains no data. We are simply passing over this URL and now work with <b>102 neighborhoods.</b>

# %%
shops.to_csv('C:\\Users\HP\Desktop\COURSERA\IBM Data Science\CAPSTONE\shops.csv', encoding='UTF-8')
print(shops.shape)
shops
# Out:
# (348, 5)
#                                  name                                           address   categories        lat        lng
# 0                         Tim Hortons                                 8129 Sheppard Ave  Coffee Shop  43.802000 -79.198169
# 1                  Tim Hortons / Esso                          Morningside and sheppard  Coffee Shop  43.801660 -79.199133
# 0                           Starbucks                               255 Morningside Ave  Coffee Shop  43.770367 -79.186313
# 1                         Tim Hortons                                  4479 Kingston Rd  Coffee Shop  43.769591 -79.187081
# 0                           Starbucks                                    300 Borough Dr  Coffee Shop  43.770037 -79.221156
# 1                       Country Style                                 136 Orton Park Rd  Coffee Shop  43.773716 -79.207027
# 0                         Tim Hortons                                   1150 Markham Rd  Coffee Shop  43.775992 -79.232135
# 1                         Tim Hortons                                   60 Tuxedo Court  Coffee Shop  43.779944 -79.232457
# 2                      Coffee Culture                                 2060 Ellesmere Rd  Coffee Shop  43.776278 -79.234026
# 0                         Tim Hortons                            2874 Eglinton Ave East  Coffee Shop  43.738992 -79.238961
# 0                         Tim Hortons                            2500 Eglinton Ave East  Coffee Shop  43.734966 -79.257889
# 1                         Tim Hortons                                678-682 Kennedy Rd  Coffee Shop  43.726895 -79.266157
# 2                         Tim Hortons                               2401 Eglinton ave e  Coffee Shop  43.732134 -79.268264
# 0                           Starbucks                                 3003 Danforth Ave  Coffee Shop  43.703634 -79.277661
# 1                         Tim Hortons                                    720 Warden Ave  Coffee Shop  43.716288 -79.283337
# 2                         Tim Hortons                                    768 Warden Ave  Coffee Shop  43.716284 -79.283337
# 0                           Starbucks                                   1156 Kennedy Rd  Coffee Shop  43.752496 -79.276393
# 1                         Tim Hortons                                  1900 Midland Ave  Coffee Shop  43.766015 -79.271084
# 2                         Tim Hortons                            2370 Lawrence Ave East  Coffee Shop  43.750066 -79.274012
# 0                         Tim Hortons                            2044 Lawrence Ave East  Coffee Shop  43.745513 -79.295214
# 0                         Tim Hortons                                   2301 Brimley Rd  Coffee Shop  43.798307 -79.272655
# 0                         Tim Hortons                                   2363 Warden Ave  Coffee Shop  43.785270 -79.309986
# 0                           Starbucks                                  3740 Midland Ave  Coffee Shop  43.816165 -79.293562
# 0                         Tim Hortons                         2900 Warden Ave, Unit 149  Coffee Shop  43.798281 -79.318317
# 1                         Tim Hortons                                3030 Birchmount Rd  Coffee Shop  43.802199 -79.308731
# 0                         Tim Hortons                                    5955 Leslie St  Coffee Shop  43.798945 -79.369644
# 1                         Tim Hortons                             2890 Steeles Ave East  Coffee Shop  43.811852 -79.359501
# 0                  Aroma Espresso Bar                              1800 Sheppard Ave. E  Coffee Shop  43.777700 -79.344652
# 1                           Starbucks                      1800 Sheppard Ave E,Unit F13  Coffee Shop  43.778287 -79.343331
# 2                         Tim Hortons                                 2500 Don Mills Rd  Coffee Shop  43.775249 -79.347740
# 3                         Tim Hortons                       70 Forest Manor Dr, Suite E  Coffee Shop  43.774965 -79.346285
# 0                         Tim Hortons                                     6001 Yonge St  Coffee Shop  43.789345 -79.417106
# 1                         Coffee Time                                     5926 yonge st  Coffee Shop  43.787138 -79.417497
# 0                           Starbucks                                     5140 Yonge St  Coffee Shop  43.768192 -79.413021
# 1                           Starbucks                                 5150 Yonge Street  Coffee Shop  43.768627 -79.413100
# 2                         Tim Hortons                                     20 Church Ave  Coffee Shop  43.773967 -79.413620
# 3                         Tim Hortons                                     4986 Yonge St  Coffee Shop  43.765616 -79.412538
# 4                         Tim Hortons                                     5383 Yonge St  Coffee Shop  43.774357 -79.413214
# 5                         Tim Hortons                                    4684 Yonge St.  Coffee Shop  43.763265 -79.405302
# 0                        Tim Horton's                                     4211 Yonge St  Coffee Shop  43.744559 -79.404403
# 0                         Tim Hortons                                    515 Drewry Ave  Coffee Shop  43.780940 -79.444231
# 0                            La Notre                                1277 York Mills Rd  Coffee Shop  43.760704 -79.325396
# 0                           Starbucks            861 York Mills Rd,York Mills & Lesmill  Coffee Shop  43.754122 -79.351724
# 1                          Second Cup                                808 York Mills Rd.  Coffee Shop  43.753805 -79.358064
# 2                       Country Style                                799 York Mills Rd.  Coffee Shop  43.752962 -79.359781
# 0                         Tim Hortons                                  843 Don Mills Rd  Coffee Shop  43.722897 -79.339117
# 1                       Delimark Cafe                                895 Don Mills Road  Coffee Shop  43.727536 -79.339547
# 0                           Starbucks                 626 Sheppard Ave W,Sheppard Plaza  Coffee Shop  43.755653 -79.439873
# 1                         Tim Hortons                             680 Sheppard Ave West  Coffee Shop  43.754767 -79.443250
# 0                           Starbucks                                 1113 Finch Ave W.  Coffee Shop  43.766485 -79.476267
# 1                         Tim Hortons                        1280 Finch Ave W, Unit 108  Coffee Shop  43.764289 -79.488790
# 2                         Tim Hortons                                     4211 Keele St  Coffee Shop  43.774266 -79.493165
# 0                         Tim Hortons                                    793 Wilson Ave  Coffee Shop  43.731740 -79.460227
# 1                         Tim Hortons                                 123 Garratt Blvd.  Coffee Shop  43.738890 -79.472242
# 0                       Country Style                                      2512 Jane St  Coffee Shop  43.740313 -79.513775
# 0                         Tim Hortons                                      3981 Jane St  Coffee Shop  43.756124 -79.515264
# 1                         Tim Hortons                                 2111 Finch Ave. W  Coffee Shop  43.754344 -79.527024
# 0                         Tim Hortons                            1733 Eglinton Ave East  Coffee Shop  43.725517 -79.313103
# 1                         Tim Hortons                                    150 Wynford Dr  Coffee Shop  43.727082 -79.327143
# 0                         Tim Hortons                                  1500 O'connor Dr  Coffee Shop  43.714401 -79.307356
# 1                Cultured Coffee Bean                               1400 O'Conner Drive  Coffee Shop  43.713249 -79.307852
# 0                      Last Drop Cafe                                    549 Sammon Ave  Coffee Shop  43.688830 -79.326002
# 1                           Starbucks                                   978 Coxwell Ave  Coffee Shop  43.695985 -79.328991
# 2                         Tim Hortons                                   825 Coxwell Ave  Coffee Shop  43.690052 -79.324800
# 0                 The Remarkable Bean                                   2242 Queen St E  Coffee Shop  43.672801 -79.287038
# 1                             Grinder                                       126 Main St  Coffee Shop  43.683073 -79.299875
# 2                           Starbucks                                  637 Kingston Rd.  Coffee Shop  43.678798 -79.298045
# 3                         Tim Hortons                                  1089 Kingston Rd  Coffee Shop  43.680799 -79.282907
# 4                         Tim Hortons                                2002 Queen St East  Coffee Shop  43.670286 -79.299733
# 5                           Starbucks                                  1020 Kingston Rd  Coffee Shop  43.680806 -79.285137
# 6                          Dip 'n Sip                                 663 Kingston Road  Coffee Shop  43.678897 -79.297745
# 0                  Aroma Espresso Bar                                    89 Laird Drive  Coffee Shop  43.705611 -79.360775
# 1                           Starbucks                                878 Eglinton Ave E  Coffee Shop  43.713553 -79.364832
# 2                         Tim Hortons                                       85 Laird Dr  Coffee Shop  43.705629 -79.361028
# 3                           Starbucks                                65 Wicksteed Ave,C  Coffee Shop  43.710342 -79.360948
# 4                         Tim Hortons                             939 Eglinton Ave East  Coffee Shop  43.713323 -79.360294
# 0                  Aroma Espresso Bar                                    89 Laird Drive  Coffee Shop  43.705611 -79.360775
# 1                           Starbucks    62-66 Overlea Boul,Building C-2, Units C5 & C6  Coffee Shop  43.707947 -79.342520
# 2                         Tim Hortons                                       85 Laird Dr  Coffee Shop  43.705629 -79.361028
# 3                         Tim Hortons                                  26 Overlea Blvd.  Coffee Shop  43.705110 -79.350595
# 0                           Starbucks                                 1417 Danforth Ave  Coffee Shop  43.682446 -79.327232
# 1               Marvel Coffee Company                                  990 Danforth Ave  Coffee Shop  43.680716 -79.337526
# 2                           Starbucks                                  888 Danforth Ave  Coffee Shop  43.679850 -79.340370
# 3                           Starbucks                                  842 Danforth Ave  Coffee Shop  43.679842 -79.340651
# 4                         Tim Hortons                                 1215 Danforth Ave  Coffee Shop  43.681436 -79.330741
# 5                           Starbucks                               604 Danforth Avenue  Coffee Shop  43.678730 -79.346188
# 6                         Tim Hortons                                      743 Pape Ave  Coffee Shop  43.679888 -79.345025
# 0                         Cafe Frappe                                 521 Danforth Ave.  Coffee Shop  43.678126 -79.348434
# 1                   Marvel Coffee Co.                                   792 Carlaw Ave.  Coffee Shop  43.678645 -79.347439
# 2                          Second Cup                                 355 Danforth Ave.  Coffee Shop  43.677333 -79.352818
# 3                           Starbucks                                  108 Danforth Ave  Coffee Shop  43.676416 -79.358466
# 4                     Si Espresso Bar                             653-671 Broadview Ave  Coffee Shop  43.675749 -79.358572
# 5                           Starbucks                                  888 Danforth Ave  Coffee Shop  43.679850 -79.340370
# 6                           Starbucks                                  842 Danforth Ave  Coffee Shop  43.679842 -79.340651
# 7                           Starbucks                               604 Danforth Avenue  Coffee Shop  43.678730 -79.346188
# 0                           Starbucks                                   1842 Queen St E  Coffee Shop  43.668370 -79.308015
# 1                     Buds Coffee Bar                                1934 Queen St East  Coffee Shop  43.669375 -79.303218
# 2                  Aroma Espresso Bar                                               NaN  Coffee Shop  43.668495 -79.306890
# 3                         Tim Hortons                          1681 Lakeshore Blvd East  Coffee Shop  43.662644 -79.309945
# 0                              Te Aro                                    983 Queen St E  Coffee Shop  43.661373 -79.338577
# 1                Mercury Espresso Bar                                 909 Queen St East  Coffee Shop  43.660806 -79.341241
# 2                           Starbucks                                    908 Queen St E  Coffee Shop  43.660640 -79.342461
# 3         Tango Palace Coffee Company                                   1156 Queen St E  Coffee Shop  43.662531 -79.333696
# 4                       Hailed Coffee                                  801 Gerrard St E  Coffee Shop  43.666900 -79.345432
# 5             Dark Horse Espresso Bar                                    630 Queen St E  Coffee Shop  43.658498 -79.352356
# 6                      The Cannonball                                   641 Queen St. E  Coffee Shop  43.658299 -79.352397
# 0                         Tim Hortons                                  2275 Bayview Ave  Coffee Shop  43.727324 -79.379563
# 0    De Mello Palheta Coffee Roasters                                     2489 Yonge St  Coffee Shop  43.711791 -79.399403
# 1                           Starbucks                                   2451 Yonge St N  Coffee Shop  43.711200 -79.399182
# 2                           Starbucks                                 39 Eglinton Ave E  Coffee Shop  43.706940 -79.396908
# 3                           Starbucks                                    2293 Yonge St.  Coffee Shop  43.707514 -79.398497
# 4                           Starbucks                             694 Mount Pleasant Rd  Coffee Shop  43.706084 -79.389355
# 5                  Aroma Espresso Bar                            2300 Yonge St, Unit C2  Coffee Shop  43.706944 -79.398413
# 6                           Starbucks                                     2630 Yonge St  Coffee Shop  43.715456 -79.400303
# 7                           Starbucks                                    2300 Yonge St.  Coffee Shop  43.707747 -79.398556
# 8                         Tim Hortons                                     2245 Yonge St  Coffee Shop  43.706589 -79.397837
# 9                         Tim Hortons                              20 Eglinton Ave West  Coffee Shop  43.706829 -79.399094
# 10                         Second Cup                       2200 Yonge St, Subway Level  Coffee Shop  43.706387 -79.398308
# 0    De Mello Palheta Coffee Roasters                                     2489 Yonge St  Coffee Shop  43.711791 -79.399403
# 1                           Starbucks                                   2451 Yonge St N  Coffee Shop  43.711200 -79.399182
# 2                           Starbucks                                     2630 Yonge St  Coffee Shop  43.715456 -79.400303
# 0                           Starbucks                             694 Mount Pleasant Rd  Coffee Shop  43.706084 -79.389355
# 1                           Starbucks                                 39 Eglinton Ave E  Coffee Shop  43.706940 -79.396908
# 2                           Starbucks                        2193 Yonge St,Unit Space C  Coffee Shop  43.705510 -79.398032
# 3                           Starbucks                                    2293 Yonge St.  Coffee Shop  43.707514 -79.398497
# 4                  Aroma Espresso Bar                            2300 Yonge St, Unit C2  Coffee Shop  43.706944 -79.398413
# 5                           Starbucks                                     1909 Yonge St  Coffee Shop  43.698399 -79.396499
# 6                           Starbucks                                    2300 Yonge St.  Coffee Shop  43.707747 -79.398556
# 0                           Starbucks                                     1495 Yonge St  Coffee Shop  43.688978 -79.394475
# 1                          Second Cup                                 2 St. Clair Ave E  Coffee Shop  43.688257 -79.393778
# 2                           Starbucks                                   5 Rose Hill Ave  Coffee Shop  43.686312 -79.393281
# 3                          Second Cup                                     1560 Yonge St  Coffee Shop  43.689814 -79.394811
# 4                       Country Style                                 21 St-Clair Ave E  Coffee Shop  43.688512 -79.393101
# 0                       Boxcar Social                                    1208 Yonge St.  Coffee Shop  43.681750 -79.391447
# 1                           Starbucks                                     1495 Yonge St  Coffee Shop  43.688978 -79.394475
# 2                           Starbucks                                 95 St Clair Ave W  Coffee Shop  43.687101 -79.398612
# 3                          Second Cup                                 2 St. Clair Ave E  Coffee Shop  43.688257 -79.393778
# 4                         Tim Hortons                              55 St Claire Av West  Coffee Shop  43.687682 -79.396840
# 5                           Starbucks                                   5 Rose Hill Ave  Coffee Shop  43.686312 -79.393281
# 6                          Second Cup                                     1560 Yonge St  Coffee Shop  43.689814 -79.394811
# 0                  Aroma Espresso Bar                                    365 Bloor St R  Coffee Shop  43.672154 -79.377885
# 1                         Tim Hortons                                 419 Bloor St East  Coffee Shop  43.672155 -79.376993
# 0                   Red Rocket Coffee                              154 Wellesley St. E.  Coffee Shop  43.666528 -79.376016
# 1                Rooster Coffee House                                     568 Jarvis St  Coffee Shop  43.669654 -79.379871
# 0                           Starbucks                                     485 Church St  Coffee Shop  43.665009 -79.380564
# 1                       Coffee Island                                    925 Bay street  Coffee Shop  43.664271 -79.386972
# 2                Rooster Coffee House                                     568 Jarvis St  Coffee Shop  43.669654 -79.379871
# 3                 Piedmont Coffee Bar                                               NaN  Coffee Shop  43.668350 -79.382500
# 4                           Starbucks        2 Bloor Street East,C3 Hudson's Bay Centre  Coffee Shop  43.670398 -79.386252
# 5                       Hailed Coffee                                   44 Gerrard St W  Coffee Shop  43.658833 -79.383684
# 6                      Jimmy's Coffee                               82 Gerrard Street W  Coffee Shop  43.658421 -79.385613
# 7                           Starbucks        50 Bloor St W,Unit C10 Holt Renfrew Centre  Coffee Shop  43.669895 -79.388175
# 0                       Tandem Coffee                                     368 King St E  Coffee Shop  43.653559 -79.361809
# 1                      Rooster Coffee                                     343 King St E  Coffee Shop  43.651900 -79.365609
# 2                                Arvo                                   17 Gristmill Ln  Coffee Shop  43.649963 -79.361442
# 3                     Sumach Espresso                                     118 Sumach St  Coffee Shop  43.658135 -79.359515
# 4                     Balzac's Coffee                                  1 Trinity Street  Coffee Shop  43.649797 -79.359142
# 5                           Starbucks                                  351 King St E,60  Coffee Shop  43.651327 -79.364329
# 6           Merchants of Green Coffee                                      2 Matilda St  Coffee Shop  43.659986 -79.354299
# 7                      NEO COFFEE BAR                        161 Frederick St, Unit 100  Coffee Shop  43.650702 -79.369259
# 8                           Starbucks                                  251 King St E,A1  Coffee Shop  43.651276 -79.368046
# 9             Dark Horse Espresso Bar                                    630 Queen St E  Coffee Shop  43.658498 -79.352356
# 10                     The Cannonball                                   641 Queen St. E  Coffee Shop  43.658299 -79.352397
# 11            Dark Horse Espresso Bar                                    416 Front St E  Coffee Shop  43.653081 -79.357078
# 12                  Fahrenheit Coffee                                    120 Lombard St  Coffee Shop  43.652384 -79.372719
# 13                           cafe 260                              260 Richmond St East  Coffee Shop  43.653183 -79.370115
# 14                    Savoury Grounds                                481 Queen St. East  Coffee Shop  43.656821 -79.358970
# 0                       Hailed Coffee                                   44 Gerrard St W  Coffee Shop  43.658833 -79.383684
# 1                         Tim Hortons                    10 Dundas St E&#x20; Suite 104  Coffee Shop  43.656755 -79.380512
# 2                      Jimmy's Coffee                               82 Gerrard Street W  Coffee Shop  43.658421 -79.385613
# 3                         Tim Hortons                                70 Gerrard St West  Coffee Shop  43.658570 -79.385123
# 4                   Fahrenheit Coffee                                    120 Lombard St  Coffee Shop  43.652384 -79.372719
# 5                           Starbucks                                  209 Victoria St.  Coffee Shop  43.654465 -79.378919
# 6                           Starbucks                                   66 Carlton St E  Coffee Shop  43.659912 -79.378575
# 0                   Fahrenheit Coffee                                    120 Lombard St  Coffee Shop  43.652384 -79.372719
# 1                       Versus Coffee                                  70 Adelaide St E  Coffee Shop  43.651213 -79.375236
# 2                      NEO COFFEE BAR                        161 Frederick St, Unit 100  Coffee Shop  43.650702 -79.369259
# 3         Sam James Coffee Bar (SJCB)                                 15 Toronto Street  Coffee Shop  43.650319 -79.376217
# 4                           Starbucks                         1 Adelaide St E,Suite 100  Coffee Shop  43.650421 -79.378202
# 5                           Starbucks                                       4 King St W  Coffee Shop  43.649386 -79.378093
# 6   Everyday Gourmet (Teas & Coffees)  93 Front St E (St. Lawrence Market, Lower Level)  Coffee Shop  43.648757 -79.371645
# 0               Pilot Coffee Roasters                                               NaN  Coffee Shop  43.645018 -79.380415
# 1   Everyday Gourmet (Teas & Coffees)  93 Front St E (St. Lawrence Market, Lower Level)  Coffee Shop  43.648757 -79.371645
# 2                      NEO COFFEE BAR                        161 Frederick St, Unit 100  Coffee Shop  43.650702 -79.369259
# 3                           Starbucks                                   181 Bay St,Path  Coffee Shop  43.646957 -79.378265
# 4                   Fahrenheit Coffee                                    120 Lombard St  Coffee Shop  43.652384 -79.372719
# 5                           Starbucks                                     81 Front St E  Coffee Shop  43.648958 -79.372621
# 0                      Jimmy's Coffee                               82 Gerrard Street W  Coffee Shop  43.658421 -79.385613
# 1                       Hailed Coffee                                   44 Gerrard St W  Coffee Shop  43.658833 -79.383684
# 2                         Tim Hortons                                70 Gerrard St West  Coffee Shop  43.658570 -79.385123
# 3                           Starbucks                                       761 Bay St.  Coffee Shop  43.659587 -79.385252
# 4                       Coffee Public                                        800 Bay St  Coffee Shop  43.660763 -79.386184
# 5                    Starbucks (MaRS)                                    101 College St  Coffee Shop  43.659242 -79.390750
# 6        The Library Specialty Coffee                                281 Dundas St West  Coffee Shop  43.654413 -79.390902
# 7                         Tim Hortons                    10 Dundas St E&#x20; Suite 104  Coffee Shop  43.656755 -79.380512
# 0                  M Square Coffee Co                              C24 - 123 Queen St W  Coffee Shop  43.651218 -79.383555
# 1               Pilot Coffee Roasters                                     100 King St W  Coffee Shop  43.648835 -79.380936
# 2                           Starbucks                         55 University Ave,Unit #3  Coffee Shop  43.646936 -79.384428
# 3             Dark Horse Espresso Bar                                       125 John St  Coffee Shop  43.648292 -79.390390
# 0               Pilot Coffee Roasters                                               NaN  Coffee Shop  43.645018 -79.380415
# 1                     Balzac's Coffee     7 Station Street (inside UP Express terminal)  Coffee Shop  43.644373 -79.383065
# 2                         Tim Hortons                              249 Queens Quay West  Coffee Shop  43.638703 -79.386215
# 3                           Starbucks                              25 York St,Unit R-18  Coffee Shop  43.643417 -79.380891
# 4                           Starbucks                                  65 Front St West  Coffee Shop  43.644581 -79.381672
# 5                           Starbucks                         55 University Ave,Unit #3  Coffee Shop  43.646936 -79.384428
# 6                  Lavazza Espression                                225 Queens Quay W.  Coffee Shop  43.639537 -79.381763
# 7                           Starbucks                                    123 Front St W  Coffee Shop  43.645102 -79.383610
# 0               Pilot Coffee Roasters                                               NaN  Coffee Shop  43.645018 -79.380415
# 1                           Starbucks                         55 University Ave,Unit #3  Coffee Shop  43.646936 -79.384428
# 2               Pilot Coffee Roasters                                     100 King St W  Coffee Shop  43.648835 -79.380936
# 3                     Balzac's Coffee     7 Station Street (inside UP Express terminal)  Coffee Shop  43.644373 -79.383065
# 4                  M Square Coffee Co                              C24 - 123 Queen St W  Coffee Shop  43.651218 -79.383555
# 0               Pilot Coffee Roasters                                     100 King St W  Coffee Shop  43.648835 -79.380936
# 1               Pilot Coffee Roasters                                               NaN  Coffee Shop  43.645018 -79.380415
# 2               Dineen @CommerceCourt                                        199 Bay St  Coffee Shop  43.648251 -79.380127
# 3                           Starbucks                                   181 Bay St,Path  Coffee Shop  43.646957 -79.378265
# 4                           Starbucks                         55 University Ave,Unit #3  Coffee Shop  43.646936 -79.384428
# 5                           Starbucks                         1 Adelaide St E,Suite 100  Coffee Shop  43.650421 -79.378202
# 6                  M Square Coffee Co                              C24 - 123 Queen St W  Coffee Shop  43.651218 -79.383555
# 7                       Versus Coffee                                  70 Adelaide St E  Coffee Shop  43.651213 -79.375236
# 0                           Starbucks                                    1740 42 Ave Rd  Coffee Shop  43.728787 -79.418340
# 1                           Starbucks                                       1887 Ave Rd  Coffee Shop  43.732564 -79.419231
# 2                         Tim Hortons                                       2005 Ave Rd  Coffee Shop  43.735356 -79.419605
# 0           The Mad Bean Coffee House                          519 Eglinton Avenue West  Coffee Shop  43.703529 -79.413698
# 1                           Starbucks                                444 Eglinton Ave W  Coffee Shop  43.704049 -79.411762
# 2                          Second Cup                                518 Eglinton Ave W  Coffee Shop  43.703583 -79.413824
# 0           The Mad Bean Coffee House                          519 Eglinton Avenue West  Coffee Shop  43.703529 -79.413698
# 1                           Starbucks                                    446 Spadina Rd  Coffee Shop  43.688998 -79.412803
# 2                           Starbucks                                444 Eglinton Ave W  Coffee Shop  43.704049 -79.411762
# 3                          Second Cup                                518 Eglinton Ave W  Coffee Shop  43.703583 -79.413824
# 0                   Creeds Coffee Bar                                     390 Dupont St  Coffee Shop  43.674100 -79.410838
# 1                           Starbucks              1 Beford Ave,One Bedford Condominium  Coffee Shop  43.668389 -79.397521
# 2                      B Espresso Bar                                   273 Bloor St. W  Coffee Shop  43.668143 -79.396087
# 0                      Little Pebbles                                160 Baldwin Street  Coffee Shop  43.654883 -79.400264
# 1            Nespresso Boutique - Bar                                159 Cumberland St.  Coffee Shop  43.669883 -79.393359
# 0                      Little Pebbles                                160 Baldwin Street  Coffee Shop  43.654883 -79.400264
# 1             Dark Horse Espresso Bar                                   215 Spadina Ave  Coffee Shop  43.650564 -79.397018
# 2                       I Deal Coffee                                  84 Nassau Street  Coffee Shop  43.655058 -79.403254
# 3                The Alternative Cafe                          443 Richmond Street West  Coffee Shop  43.647852 -79.397014
# 0                           Starbucks                              10 Lower Spadina Ave  Coffee Shop  43.637735 -79.392203
# 1                           Starbucks                                   600 Fleet St,18  Coffee Shop  43.636920 -79.399840
# 0               Pilot Coffee Roasters                                               NaN  Coffee Shop  43.645018 -79.380415
# 1                           Starbucks                                   181 Bay St,Path  Coffee Shop  43.646957 -79.378265
# 2   Everyday Gourmet (Teas & Coffees)  93 Front St E (St. Lawrence Market, Lower Level)  Coffee Shop  43.648757 -79.371645
# 3                      NEO COFFEE BAR                        161 Frederick St, Unit 100  Coffee Shop  43.650702 -79.369259
# 4                   Fahrenheit Coffee                                    120 Lombard St  Coffee Shop  43.652384 -79.372719
# 5                           Starbucks                                     81 Front St E  Coffee Shop  43.648958 -79.372621
# 6               Pilot Coffee Roasters                                     100 King St W  Coffee Shop  43.648835 -79.380936
# 7                       Versus Coffee                                  70 Adelaide St E  Coffee Shop  43.651213 -79.375236
# 8                           Starbucks                                       4 King St W  Coffee Shop  43.649386 -79.378093
# 9               Dineen @CommerceCourt                                        199 Bay St  Coffee Shop  43.648251 -79.380127
# 0                           Starbucks                         55 University Ave,Unit #3  Coffee Shop  43.646936 -79.384428
# 1               Pilot Coffee Roasters                                     100 King St W  Coffee Shop  43.648835 -79.380936
# 2               Pilot Coffee Roasters                                               NaN  Coffee Shop  43.645018 -79.380415
# 3                  M Square Coffee Co                              C24 - 123 Queen St W  Coffee Shop  43.651218 -79.383555
# 4                     Balzac's Coffee     7 Station Street (inside UP Express terminal)  Coffee Shop  43.644373 -79.383065
# 0                         Tim Hortons                                  171 Bentworth St  Coffee Shop  43.719427 -79.467995
# 1                         Tim Hortons                                  3140 Dufferin St  Coffee Shop  43.717155 -79.456574
# 2                         Tim Hortons                                  3321 Dufferin St  Coffee Shop  43.722954 -79.456065
# 0                           Starbucks                                  3401 Dufferin St  Coffee Shop  43.715713 -79.443717
# 1                         Tim Hortons                             750 Lawrence Ave West  Coffee Shop  43.716366 -79.446820
# 0                           Starbucks                                900 Eglinton Ave W  Coffee Shop  43.700598 -79.427604
# 1                           Starbucks                             901 Eglinton Ave West  Coffee Shop  43.700675 -79.433673
# 2              Timothy's World Coffee                               1070 Eglinton Ave W  Coffee Shop  43.699907 -79.430904
# 0                         Tim Hortons                                 1801 Eglinton Ave  Coffee Shop  43.695716 -79.449139
# 0                           Starbucks                                     657 Dupont St  Coffee Shop  43.671585 -79.421366
# 1                   Black Rock Coffee                                    677 Bloor St W  Coffee Shop  43.663955 -79.416575
# 2                       Coffee Pocket                                   688a Bloor St W  Coffee Shop  43.663949 -79.416960
# 3                  The Good Neighbour                                    678 Bloor St W  Coffee Shop  43.663983 -79.416640
# 4                    Rustle And Still                             605 Bloor Street West  Coffee Shop  43.664665 -79.412952
# 5                        Volta Coffee                               866 Bathurst Street  Coffee Shop  43.667314 -79.412145
# 6                     Hub Coffee Shop                                983 Dovercourt Rd.  Coffee Shop  43.666932 -79.431510
# 7             Dark Horse Espresso Bar                                     120 Geary Ave  Coffee Shop  43.670468 -79.434878
# 0                         Hale Coffee                                   300 Campbell St  Coffee Shop  43.665532 -79.449949
# 1                    Wallace Espresso                                  188 Wallace Ave.  Coffee Shop  43.662367 -79.444227
# 2                           Starbucks                        1228 St. Clair Avenue West  Coffee Shop  43.677574 -79.445221
# 3             Dark Horse Espresso Bar                                     120 Geary Ave  Coffee Shop  43.670468 -79.434878
# 4                     Hub Coffee Shop                                983 Dovercourt Rd.  Coffee Shop  43.666932 -79.431510
# 0                      Jimmy's Coffee                                  15 Ossington Ave  Coffee Shop  43.644521 -79.418908
# 1                       i deal coffee                                 162 Ossington Ave  Coffee Shop  43.647844 -79.420294
# 2                  The Tampered Press                                  256 Crawford St.  Coffee Shop  43.650062 -79.417280
# 3                       Tucana Coffee                                 1413 Dundas St. W  Coffee Shop  43.649549 -79.429147
# 0                           Starbucks                        1200 King St W,Old Toronto  Coffee Shop  43.638995 -79.427652
# 1                  Louie Craft Coffee                                    1187 King St W  Coffee Shop  43.639284 -79.425620
# 2     Liberty Village Market and Cafe                               65 Jefferson Avenue  Coffee Shop  43.638057 -79.421493
# 3                     Balzac's Coffee                         43 Hanna Avenue, Unit 123  Coffee Shop  43.638611 -79.419421
# 4                         Tim Hortons                               171 East Liberty St  Coffee Shop  43.637865 -79.418923
# 0                           Starbucks                   20 Innovation Drive, Building B  Coffee Shop  43.719458 -79.480735
# 1                         Tim Hortons                            Meadowvale Town Centre  Coffee Shop  43.719431 -79.480723
# 2                         Coffee Time                               1575 Lawrence Ave W  Coffee Shop  43.705864 -79.488573
# 0              Timothy's World Coffee                                    Eglinton Ave W  Coffee Shop  43.690072 -79.474599
# 0                         Tim Hortons                                       895 Jane St  Coffee Shop  43.677096 -79.495507
# 1                         Tim Hortons                 2571 St Clair Ave West, Unit # E1  Coffee Shop  43.667696 -79.488003
# 2                         Tim Hortons                               3487 Dundas St West  Coffee Shop  43.665400 -79.488223
# 3                Caboose Coffee House                             3333 Dundas St. West   Coffee Shop  43.665574 -79.480981
# 0                           Hula Girl                                2473 Dundas St. W.  Coffee Shop  43.659785 -79.453634
# 1                    Crema Coffee Co.                                 3079 Dundas St. W  Coffee Shop  43.665434 -79.472137
# 2                           Starbucks                                  3077 Dundas St W  Coffee Shop  43.665365 -79.472017
# 3                         Tim Hortons                               110 West Toronto St  Coffee Shop  43.668636 -79.470522
# 4                         Tim Hortons                                1728 Bloor St West  Coffee Shop  43.655302 -79.458742
# 5                         Tim Hortons                                  3157 Dundas St W  Coffee Shop  43.665382 -79.475075
# 0           Reunion Island Coffee Bar                              385 Roncesvalles Ave  Coffee Shop  43.650463 -79.450610
# 1                    Lit Espresso Bar                           221 Roncesvalles Avenue  Coffee Shop  43.645846 -79.448830
# 2             Outpost Coffee Roasters                               1578 Bloor St. West  Coffee Shop  43.656059 -79.454106
# 3                         Tim Hortons                              175 Roncesvalles Ave  Coffee Shop  43.644459 -79.448054
# 4                           Starbucks                                  2201 Dundas St W  Coffee Shop  43.653588 -79.451466
# 0                Wibke's Espresso Bar                                  2465 Bloor St. W  Coffee Shop  43.649132 -79.484802
# 1                           Starbucks                                     2210 Bloor St  Coffee Shop  43.651253 -79.475839
# 2                      Lit Cafe + Bar                                               NaN  Coffee Shop  43.651379 -79.475380
# 3                         Tim Hortons                                2485 Bloor St West  Coffee Shop  43.648526 -79.485066
# 4              Timothy's World Coffee                                   2190 Bloor St W  Coffee Shop  43.651525 -79.474957
# 5                         Tim Hortons                                       Willard ave  Coffee Shop  43.658110 -79.488176
# 6              Timothy's World Coffee                                   2402 Bloor St W  Coffee Shop  43.649835 -79.483069
# 7                         Tim Hortons                                2150 Bloor St West  Coffee Shop  43.651969 -79.473519
# 8                 The Coffee Bouquets                               7 Riverview Gardens  Coffee Shop  43.648785 -79.485940
# 0                       Coffee Island                                    925 Bay street  Coffee Shop  43.664271 -79.386972
# 1                      Jimmy's Coffee                               82 Gerrard Street W  Coffee Shop  43.658421 -79.385613
# 2                       Hailed Coffee                                   44 Gerrard St W  Coffee Shop  43.658833 -79.383684
# 3                       Coffee Public                                        800 Bay St  Coffee Shop  43.660763 -79.386184
# 4                           Starbucks                                       761 Bay St.  Coffee Shop  43.659587 -79.385252
# 5                         Tim Hortons                                70 Gerrard St West  Coffee Shop  43.658570 -79.385123
# 6                    Starbucks (MaRS)                                    101 College St  Coffee Shop  43.659242 -79.390750
# 7                           Starbucks                           585 University Ave,R-16  Coffee Shop  43.658557 -79.390196
# 8                           Starbucks                                     485 Church St  Coffee Shop  43.665009 -79.380564
# 0                         Tim Hortons                                     4567 Dixie Rd  Coffee Shop  43.636293 -79.615655
# 1                         Tim Hortons                                     5014 Dixie Rd  Coffee Shop  43.635648 -79.621765
# 2                           Starbucks                                     5067 Dixie Rd  Coffee Shop  43.636888 -79.621020
# 3                         Tim Hortons                                   4880 Tahoe Blvd  Coffee Shop  43.641732 -79.608210
# 4                         Tim Hortons                                   1520 Aimco Blvd  Coffee Shop  43.638667 -79.623676
# 0         Tango Palace Coffee Company                                   1156 Queen St E  Coffee Shop  43.662531 -79.333696
# 1                           Starbucks                      1015 Lakeshore Blvd E,CRU #4  Coffee Shop  43.659678 -79.328292
# 2                         Tim Hortons                          1681 Lakeshore Blvd East  Coffee Shop  43.662644 -79.309945
# 0        Big Guy's Little Coffee Shop                             2861 Lakeshore Blvd W  Coffee Shop  43.601359 -79.502480
# 0                         Tim Hortons                                   435 Browns Line  Coffee Shop  43.602396 -79.545048
# 0                           Starbucks                                   2940 Bloor St W  Coffee Shop  43.648292 -79.507750
# 1                           Starbucks                                   3079 Bloor St W  Coffee Shop  43.646678 -79.514139
# 2                           Starbucks                              4242 Dundas Street W  Coffee Shop  43.660003 -79.513677
# 3                         Tim Hortons                                3071 Bloor St West  Coffee Shop  43.646579 -79.513853
# 0                         Tim Hortons                                1084 Islington Ave  Coffee Shop  43.635973 -79.520597
# 1                         Tim Hortons                                1000 The Queensway  Coffee Shop  43.623671 -79.515674
# 2                         Tim Hortons                                1025 The Queensway  Coffee Shop  43.620900 -79.515340
# 0                         Tim Hortons                              555 Burnhamthorpe Rd  Coffee Shop  43.644705 -79.567659
# 0                         Tim Hortons                            2013 Lawrence Ave West  Coffee Shop  43.700815 -79.511638
# 1              Tim Horton's / Wendy's                               2013 Lawrence Ave W  Coffee Shop  43.700910 -79.511692
# 0                           Starbucks                                1564 Royal York Rd  Coffee Shop  43.696249 -79.533117
# 0                       Country Style                                      1935 Kipling  Coffee Shop  43.694366 -79.557439
# 0                         Tim Hortons                               6220 Finch Ave West  Coffee Shop  43.742015 -79.589690
# 0                         Tim Hortons                               116 Queens Plate Dr  Coffee Shop  43.714657 -79.593716

# %% [markdown]
# Now we retrieve each URL and extract data for all business by neighborhood.

# %%
cust = pd.DataFrame() # Data issues may require me to append to my dataframe in chunks. So I define it outside that code.

# %%
neighlist = []

x = 0

while x < 103 :

    custresults = requests.get(URLs[x]).json()

    def get_category_type(row):
        try:
            categories_list = row['categories']
        except:
            categories_list = row['venue.categories']
        
        if len(categories_list) == 0:
            return None
        else:
            return categories_list[0]['name']

    custvenues = custresults['response']['groups'][0]['items']
    
    nearby_custvenues = json_normalize(custvenues) # flatten JSON

    # filter columns
    filtered_columns = ['venue.name', 'venue.location.address', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
    nearby_custvenues = nearby_custvenues.loc[:, filtered_columns]

    # filter the category for each row
    nearby_custvenues['venue.categories'] = nearby_custvenues.apply(get_category_type, axis=1)

    # clean columns
    nearby_custvenues.columns = [col.split(".")[-1] for col in nearby_custvenues.columns]

    dfven = nearby_custvenues
       
    if not dfven.empty :
        
        
        cust = cust.append(dfven)
        neighlist.append(dftor.iloc[x]['Neighbourhood'])
        #print(x, '!!!', dftor.iloc[x]['PostalCode'], dftor.iloc[x]['Neighbourhood'], dfven.shape)
        
    x = x + 1
    
    if x == 16 : x = x + 1 # One URL causes FourSquare to reject our data request. We are skipping this URL.

# %% [markdown]
# We have produced a data frame with <b>4853 businesses in Toronto.</b> One URL (index = 16) causes an issue with FourSquare, because it contains no data. We are simply passing over this URL and now work with <b>102 neighborhoods.</b>

# %%
columns = ['lat', 'lng']
cust.drop(columns, inplace=True, axis=1)
cust.to_csv('C:\\Users\HP\Desktop\COURSERA\IBM Data Science\CAPSTONE\cust.csv', encoding='UTF-8')
print(cust.shape)
cust.head()
# Out:
# (4852, 3)
#                  name               address            categories
# 0  Images Salon & Spa   8130 Sheppard Ave E                   Spa
# 1      Caribbean Wave        875 Milner Ave  Caribbean Restaurant
# 2             Wendy's  8129 Sheppard Avenue  Fast Food Restaurant
# 3            Harvey's        853 Milner Ave  Fast Food Restaurant
# 4             Wendy's                   NaN  Fast Food Restaurant

# %% [markdown]
# # RESULTS

# %% [markdown]
# The three deliverables requested by Cafn8 are presented below. To produce these tables for Cafn8, data was collected from four sources (Wikipedia, Cognitive Class, FourSquare, and Cafn8). We used python to collect and handle the data and used Microsoft Excel to process some of it.
#
# Preparing a sales prospecting resource for indpendent contractor sales agents does not demand a very high degree of analytical work. It does offer a basis for the client to perform analysis as a practitioner in their field, however. This project is an example of Data Science as a collection process. Cafn8 knows what they want, and for their purposes this information will provide meaningful value.
#
# Deliverables are large but presented in full for your inspection. In addition to this report, Cafn8 is being provided with Microsoft Excel .xls/.csv files as per their request.

# %% [markdown]
# <b>A list of coffee shops in Toronto, by neighborhood (with Terriscore)</b>

# %%
final = pd.read_csv('C:\\Users\HP\Desktop\COURSERA\IBM Data Science\CAPSTONE\COFFEESHOPS.csv', encoding="ISO-8859-1")

final = final.fillna("")

print(final.shape)
final
# Out:
# (348, 4)
#                            COFFEE SHOP                                           ADDRESS                                       NEIGHBORHOOD TERRISCORE
# 0                          Tim Hortons                                 8129 Sheppard Ave                                 M1B Rouge, Malvern         18
# 1                   Tim Hortons / Esso                          Morningside and sheppard
# 2                            Starbucks                               255 Morningside Ave              M1E Guildwood, Morningside, West Hill         14
# 3                          Tim Hortons                                  4479 Kingston Rd
# 4                            Starbucks                                    300 Borough Dr                                         M1G Woburn          6
# 5                        Country Style                                 136 Orton Park Rd
# 6                          Tim Hortons                                   1150 Markham Rd                                      M1H Cedarbrae         20
# 7                          Tim Hortons                                   60 Tuxedo Court
# 8                       Coffee Culture                                 2060 Ellesmere Rd
# 9                          Tim Hortons                            2874 Eglinton Ave East                            M1J Scarborough Village          7
# 10                         Tim Hortons                            2500 Eglinton Ave East    M1K East Birchmount Park, Ionview, Kennedy Park         12
# 11                         Tim Hortons                                678-682 Kennedy Rd
# 12                         Tim Hortons                               2401 Eglinton ave e
# 13                           Starbucks                                 3003 Danforth Ave                M1L Clairlea, Golden Mile, Oakridge         11
# 14                         Tim Hortons                                    720 Warden Ave
# 15                         Tim Hortons                                    768 Warden Ave
# 16                           Starbucks                                   1156 Kennedy Rd   M1P Dorset Park, Scarborough Town Centre, Wex...         40
# 17                         Tim Hortons                                  1900 Midland Ave
# 18                         Tim Hortons                            2370 Lawrence Ave East
# 19                         Tim Hortons                            2044 Lawrence Ave East                              M1R Maryvale, Wexford         16
# 20                         Tim Hortons                                   2301 Brimley Rd                                      M1S Agincourt         37
# 21                         Tim Hortons                                   2363 Warden Ave        M1T Clarks Corners, Sullivan, Tam O'Shanter         20
# 22                           Starbucks                                  3740 Midland Ave   M1V Agincourt North, L'Amoreaux East, Millike...         21
# 23                         Tim Hortons                         2900 Warden Ave, Unit 149                  M1W L'Amoreaux West, Steeles West         14
# 24                         Tim Hortons                                3030 Birchmount Rd
# 25                         Tim Hortons                                    5955 Leslie St                              M2H Hillcrest Village         12
# 26                         Tim Hortons                             2890 Steeles Ave East
# 27                  Aroma Espresso Bar                              1800 Sheppard Ave. E                   M2J Fairview, Henry Farm, Oriole         35
# 28                           Starbucks                      1800 Sheppard Ave E,Unit F13
# 29                         Tim Hortons                                 2500 Don Mills Rd
# 30                         Tim Hortons                       70 Forest Manor Dr, Suite E
# 31                         Tim Hortons                                     6001 Yonge St                        M2M Newtonbrook, Willowdale         24
# 32                         Coffee Time                                     5926 yonge st
# 33                           Starbucks                                     5140 Yonge St                               M2N Willowdale South         80
# 34                           Starbucks                                 5150 Yonge Street
# 35                         Tim Hortons                                     20 Church Ave
# 36                         Tim Hortons                                     4986 Yonge St
# 37                         Tim Hortons                                     5383 Yonge St
# 38                         Tim Hortons                                    4684 Yonge St.
# 39                        Tim Horton's                                     4211 Yonge St                                M2P York Mills West          7
# 40                         Tim Hortons                                    515 Drewry Ave                                M2R Willowdale West          7
# 41                            La Notre                                1277 York Mills Rd                                      M3A Parkwoods         18
# 42                           Starbucks            861 York Mills Rd,York Mills & Lesmill                                M3B Don Mills North         23
# 43                          Second Cup                                808 York Mills Rd.
# 44                       Country Style                                799 York Mills Rd.
# 45                         Tim Hortons                                  843 Don Mills Rd               M3C Flemingdon Park, Don Mills South         40
# 46                       Delimark Cafe                                895 Don Mills Road
# 47                           Starbucks                 626 Sheppard Ave W,Sheppard Plaza   M3H Bathurst Manor, Downsview North, Wilson H...         12
# 48                         Tim Hortons                             680 Sheppard Ave West
# 49                           Starbucks                                 1113 Finch Ave W.                M3J Northwood Park, York University         14
# 50                         Tim Hortons                        1280 Finch Ave W, Unit 108
# 51                         Tim Hortons                                     4211 Keele St
# 52                         Tim Hortons                                    793 Wilson Ave                    M3K CFB Toronto, Downsview East         12
# 53                         Tim Hortons                                 123 Garratt Blvd.
# 54                       Country Style                                      2512 Jane St                                 M3L Downsview West          6
# 55                         Tim Hortons                                      3981 Jane St                            M3N Downsview Northwest         24
# 56                         Tim Hortons                                 2111 Finch Ave. W
# 57                         Tim Hortons                            1733 Eglinton Ave East                               M4A Victoria Village          7
# 58                         Tim Hortons                                    150 Wynford Dr
# 59                         Tim Hortons                                  1500 O'connor Dr                M4B Woodbine Gardens, Parkview Hill         15
# 60                Cultured Coffee Bean                               1400 O'Conner Drive
# 61                      Last Drop Cafe                                    549 Sammon Ave                               M4C Woodbine Heights         18
# 62                           Starbucks                                   978 Coxwell Ave
# 63                         Tim Hortons                                   825 Coxwell Ave
# 64                 The Remarkable Bean                                   2242 Queen St E                                    M4E The Beaches         45
# 65                             Grinder                                       126 Main St
# 66                           Starbucks                                  637 Kingston Rd.
# 67                         Tim Hortons                                  1089 Kingston Rd
# 68                         Tim Hortons                                2002 Queen St East
# 69                           Starbucks                                  1020 Kingston Rd
# 70                          Dip 'n Sip                                 663 Kingston Road
# 71                  Aroma Espresso Bar                                    89 Laird Drive                                        M4G Leaside         46
# 72                           Starbucks                                878 Eglinton Ave E
# 73                         Tim Hortons                                       85 Laird Dr
# 74                           Starbucks                                65 Wicksteed Ave,C
# 75                         Tim Hortons                             939 Eglinton Ave East
# 76                  Aroma Espresso Bar                                    89 Laird Drive                               M4H Thorncliffe Park         32
# 77                           Starbucks    62-66 Overlea Boul,Building C-2, Units C5 & C6
# 78                         Tim Hortons                                       85 Laird Dr
# 79                         Tim Hortons                                  26 Overlea Blvd.
# 80                           Starbucks                                 1417 Danforth Ave                                   M4J East Toronto         87
# 81               Marvel Coffee Company                                  990 Danforth Ave
# 82                           Starbucks                                  888 Danforth Ave
# 83                           Starbucks                                  842 Danforth Ave
# 84                         Tim Hortons                                 1215 Danforth Ave
# 85                           Starbucks                               604 Danforth Avenue
# 86                         Tim Hortons                                      743 Pape Ave
# 87                         Cafe Frappe                                 521 Danforth Ave.                   M4K The Danforth West, Riverdale         74
# 88                   Marvel Coffee Co.                                   792 Carlaw Ave.
# 89                          Second Cup                                 355 Danforth Ave.
# 90                           Starbucks                                  108 Danforth Ave
# 91                     Si Espresso Bar                             653-671 Broadview Ave
# 92                           Starbucks                                  888 Danforth Ave
# 93                           Starbucks                                  842 Danforth Ave
# 94                           Starbucks                               604 Danforth Avenue
# 95                           Starbucks                                   1842 Queen St E                 M4L The Beaches West, India Bazaar         55
# 96                     Buds Coffee Bar                                1934 Queen St East
# 97                  Aroma Espresso Bar
# 98                         Tim Hortons                          1681 Lakeshore Blvd East
# 99                              Te Aro                                    983 Queen St E                                M4M Studio District         83
# 100               Mercury Espresso Bar                                 909 Queen St East
# 101                          Starbucks                                    908 Queen St E
# 102        Tango Palace Coffee Company                                   1156 Queen St E
# 103                      Hailed Coffee                                  801 Gerrard St E
# 104            Dark Horse Espresso Bar                                    630 Queen St E
# 105                     The Cannonball                                   641 Queen St. E
# 106                        Tim Hortons                                  2275 Bayview Ave                                  M4N Lawrence Park          7
# 107   De Mello Palheta Coffee Roasters                                     2489 Yonge St                               M4P Davisville North         78
# 108                          Starbucks                                   2451 Yonge St N
# 109                          Starbucks                                 39 Eglinton Ave E
# 110                          Starbucks                                    2293 Yonge St.
# 111                          Starbucks                             694 Mount Pleasant Rd
# 112                 Aroma Espresso Bar                            2300 Yonge St, Unit C2
# 113                          Starbucks                                     2630 Yonge St
# 114                          Starbucks                                    2300 Yonge St.
# 115                        Tim Hortons                                     2245 Yonge St
# 116                        Tim Hortons                              20 Eglinton Ave West
# 117                         Second Cup                       2200 Yonge St, Subway Level
# 118   De Mello Palheta Coffee Roasters                                     2489 Yonge St                             M4R North Toronto West         33
# 119                          Starbucks                                   2451 Yonge St N
# 120                          Starbucks                                     2630 Yonge St
# 121                          Starbucks                             694 Mount Pleasant Rd                                     M4S Davisville         84
# 122                          Starbucks                                 39 Eglinton Ave E
# 123                          Starbucks                        2193 Yonge St,Unit Space C
# 124                          Starbucks                                    2293 Yonge St.
# 125                 Aroma Espresso Bar                            2300 Yonge St, Unit C2
# 126                          Starbucks                                     1909 Yonge St
# 127                          Starbucks                                    2300 Yonge St.
# 128                          Starbucks                                     1495 Yonge St                    M4T Moore Park, Summerhill East         42
# 129                         Second Cup                                 2 St. Clair Ave E
# 130                          Starbucks                                   5 Rose Hill Ave
# 131                         Second Cup                                     1560 Yonge St
# 132                      Country Style                                 21 St-Clair Ave E
# 133                      Boxcar Social                                    1208 Yonge St.   M4V Deer Park, Forest Hill SE, Rathnelly, Sou...         55
# 134                          Starbucks                                     1495 Yonge St
# 135                          Starbucks                                 95 St Clair Ave W
# 136                         Second Cup                                 2 St. Clair Ave E
# 137                        Tim Hortons                              55 St Claire Av West
# 138                          Starbucks                                   5 Rose Hill Ave
# 139                         Second Cup                                     1560 Yonge St
# 140                 Aroma Espresso Bar                                    365 Bloor St R                                       M4W Rosedale          8
# 141                        Tim Hortons                                 419 Bloor St East
# 142                  Red Rocket Coffee                              154 Wellesley St. E.                    M4X Cabbagetown, St. James Town         36
# 143               Rooster Coffee House                                     568 Jarvis St
# 144                          Starbucks                                     485 Church St                           M4Y Church and Wellesley         77
# 145                      Coffee Island                                    925 Bay street
# 146               Rooster Coffee House                                     568 Jarvis St
# 147                Piedmont Coffee Bar
# 148                          Starbucks        2 Bloor Street East,C3 Hudson's Bay Centre
# 149                      Hailed Coffee                                   44 Gerrard St W
# 150                     Jimmy's Coffee                               82 Gerrard Street W
# 151                          Starbucks        50 Bloor St W,Unit C10 Holt Renfrew Centre
# 152                      Tandem Coffee                                     368 King St E                      M5A Harbourfront, Regent Park         78
# 153                     Rooster Coffee                                     343 King St E
# 154                               Arvo                                   17 Gristmill Ln
# 155                    Sumach Espresso                                     118 Sumach St
# 156                    Balzac's Coffee                                  1 Trinity Street
# 157                          Starbucks                                  351 King St E,60
# 158          Merchants of Green Coffee                                      2 Matilda St
# 159                     NEO COFFEE BAR                        161 Frederick St, Unit 100
# 160                          Starbucks                                  251 King St E,A1
# 161            Dark Horse Espresso Bar                                    630 Queen St E
# 162                     The Cannonball                                   641 Queen St. E
# 163            Dark Horse Espresso Bar                                    416 Front St E
# 164                  Fahrenheit Coffee                                    120 Lombard St
# 165                           cafe 260                              260 Richmond St East
# 166                    Savoury Grounds                                481 Queen St. East
# 167                      Hailed Coffee                                   44 Gerrard St W                       M5B Ryerson, Garden District         76
# 168                        Tim Hortons                    10 Dundas St E&#x20; Suite 104
# 169                     Jimmy's Coffee                               82 Gerrard Street W
# 170                        Tim Hortons                                70 Gerrard St West
# 171                  Fahrenheit Coffee                                    120 Lombard St
# 172                          Starbucks                                  209 Victoria St.
# 173                          Starbucks                                   66 Carlton St E
# 174                  Fahrenheit Coffee                                    120 Lombard St                                 M5C St. James Town         71
# 175                      Versus Coffee                                  70 Adelaide St E
# 176                     NEO COFFEE BAR                        161 Frederick St, Unit 100
# 177        Sam James Coffee Bar (SJCB)                                 15 Toronto Street
# 178                          Starbucks                         1 Adelaide St E,Suite 100
# 179                          Starbucks                                       4 King St W
# 180  Everyday Gourmet (Teas & Coffees)  93 Front St E (St. Lawrence Market, Lower Level)
# 181              Pilot Coffee Roasters                                                                                      M5E Berczy Park         61
# 182  Everyday Gourmet (Teas & Coffees)  93 Front St E (St. Lawrence Market, Lower Level)
# 183                     NEO COFFEE BAR                        161 Frederick St, Unit 100
# 184                          Starbucks                                   181 Bay St,Path
# 185                  Fahrenheit Coffee                                    120 Lombard St
# 186                          Starbucks                                     81 Front St E
# 187                     Jimmy's Coffee                               82 Gerrard Street W                             M5G Central Bay Street         77
# 188                      Hailed Coffee                                   44 Gerrard St W
# 189                        Tim Hortons                                70 Gerrard St West
# 190                          Starbucks                                       761 Bay St.
# 191                      Coffee Public                                        800 Bay St
# 192                   Starbucks (MaRS)                                    101 College St
# 193       The Library Specialty Coffee                                281 Dundas St West
# 194                        Tim Hortons                    10 Dundas St E&#x20; Suite 104
# 195                 M Square Coffee Co                              C24 - 123 Queen St W                       M5H Adelaide, King, Richmond         87
# 196              Pilot Coffee Roasters                                     100 King St W
# 197                          Starbucks                         55 University Ave,Unit #3
# 198            Dark Horse Espresso Bar                                       125 John St
# 199              Pilot Coffee Roasters                                                     M5J Harbourfront East, Toronto Islands, Union...         73
# 200                    Balzac's Coffee     7 Station Street (inside UP Express terminal)
# 201                        Tim Hortons                              249 Queens Quay West
# 202                          Starbucks                              25 York St,Unit R-18
# 203                          Starbucks                                  65 Front St West
# 204                          Starbucks                         55 University Ave,Unit #3
# 205                 Lavazza Espression                                225 Queens Quay W.
# 206                          Starbucks                                    123 Front St W
# 207              Pilot Coffee Roasters                                                         M5K Design Exchange, Toronto Dominion Centre         71
# 208                          Starbucks                         55 University Ave,Unit #3
# 209              Pilot Coffee Roasters                                     100 King St W
# 210                    Balzac's Coffee     7 Station Street (inside UP Express terminal)
# 211                 M Square Coffee Co                              C24 - 123 Queen St W
# 212              Pilot Coffee Roasters                                     100 King St W                 M5L Commerce Court, Victoria Hotel         67
# 213              Pilot Coffee Roasters
# 214              Dineen @CommerceCourt                                        199 Bay St
# 215                          Starbucks                                   181 Bay St,Path
# 216                          Starbucks                         55 University Ave,Unit #3
# 217                          Starbucks                         1 Adelaide St E,Suite 100
# 218                 M Square Coffee Co                              C24 - 123 Queen St W
# 219                      Versus Coffee                                  70 Adelaide St E
# 220                          Starbucks                                    1740 42 Ave Rd              M5M Bedford Park, Lawrence Manor East         33
# 221                          Starbucks                                       1887 Ave Rd
# 222                        Tim Hortons                                       2005 Ave Rd
# 223          The Mad Bean Coffee House                          519 Eglinton Avenue West                                       M5N Roselawn         27
# 224                          Starbucks                                444 Eglinton Ave W
# 225                         Second Cup                                518 Eglinton Ave W
# 226          The Mad Bean Coffee House                          519 Eglinton Avenue West            M5P Forest Hill North, Forest Hill West         36
# 227                          Starbucks                                    446 Spadina Rd
# 228                          Starbucks                                444 Eglinton Ave W
# 229                         Second Cup                                518 Eglinton Ave W
# 230                  Creeds Coffee Bar                                     390 Dupont St            M5R The Annex, North Midtown, Yorkville         84
# 231                          Starbucks              1 Beford Ave,One Bedford Condominium
# 232                     B Espresso Bar                                   273 Bloor St. W
# 233                     Little Pebbles                                160 Baldwin Street                 M5S Harbord, University of Toronto         89
# 234           Nespresso Boutique - Bar                                159 Cumberland St.
# 235                     Little Pebbles                                160 Baldwin Street      M5T Chinatown, Grange Park, Kensington Market         92
# 236            Dark Horse Espresso Bar                                   215 Spadina Ave
# 237                      I Deal Coffee                                  84 Nassau Street
# 238               The Alternative Cafe                          443 Richmond Street West
# 239                          Starbucks                              10 Lower Spadina Ave   M5V CN Tower, Bathurst Quay, Island airport, ...          7
# 240                          Starbucks                                   600 Fleet St,18
# 241              Pilot Coffee Roasters                                                                  M5W Stn A PO Boxes 25 The Esplanade         62
# 242                          Starbucks                                   181 Bay St,Path
# 243  Everyday Gourmet (Teas & Coffees)  93 Front St E (St. Lawrence Market, Lower Level)
# 244                     NEO COFFEE BAR                        161 Frederick St, Unit 100
# 245                  Fahrenheit Coffee                                    120 Lombard St
# 246                          Starbucks                                     81 Front St E
# 247              Pilot Coffee Roasters                                     100 King St W
# 248                      Versus Coffee                                  70 Adelaide St E
# 249                          Starbucks                                       4 King St W
# 250              Dineen @CommerceCourt                                        199 Bay St
# 251                          Starbucks                         55 University Ave,Unit #3         M5X First Canadian Place, Underground city         76
# 252              Pilot Coffee Roasters                                     100 King St W
# 253              Pilot Coffee Roasters
# 254                 M Square Coffee Co                              C24 - 123 Queen St W
# 255                    Balzac's Coffee     7 Station Street (inside UP Express terminal)
# 256                        Tim Hortons                                  171 Bentworth St               M6A Lawrence Heights, Lawrence Manor         48
# 257                        Tim Hortons                                  3140 Dufferin St
# 258                        Tim Hortons                                  3321 Dufferin St
# 259                          Starbucks                                  3401 Dufferin St                                      M6B Glencairn         29
# 260                        Tim Hortons                             750 Lawrence Ave West
# 261                          Starbucks                                900 Eglinton Ave W                             M6C Humewood-Cedarvale         11
# 262                          Starbucks                             901 Eglinton Ave West
# 263             Timothy's World Coffee                               1070 Eglinton Ave W
# 264                        Tim Hortons                                 1801 Eglinton Ave                            M6E Caledonia-Fairbanks         19
# 265                          Starbucks                                     657 Dupont St                                       M6G Christie         79
# 266                  Black Rock Coffee                                    677 Bloor St W
# 267                      Coffee Pocket                                   688a Bloor St W
# 268                 The Good Neighbour                                    678 Bloor St W
# 269                   Rustle And Still                             605 Bloor Street West
# 270                       Volta Coffee                               866 Bathurst Street
# 271                    Hub Coffee Shop                                983 Dovercourt Rd.
# 272            Dark Horse Espresso Bar                                     120 Geary Ave
# 273                        Hale Coffee                                   300 Campbell St                   M6H Dovercourt Village, Dufferin         64
# 274                   Wallace Espresso                                  188 Wallace Ave.
# 275                          Starbucks                        1228 St. Clair Avenue West
# 276            Dark Horse Espresso Bar                                     120 Geary Ave
# 277                    Hub Coffee Shop                                983 Dovercourt Rd.
# 278                     Jimmy's Coffee                                  15 Ossington Ave                       M6J Little Portugal, Trinity         88
# 279                      i deal coffee                                 162 Ossington Ave
# 280                 The Tampered Press                                  256 Crawford St.
# 281                      Tucana Coffee                                 1413 Dundas St. W
# 282                          Starbucks                        1200 King St W,Old Toronto   M6K Brockton, Exhibition Place, Parkdale Village         90
# 283                 Louie Craft Coffee                                    1187 King St W
# 284    Liberty Village Market and Cafe                               65 Jefferson Avenue
# 285                    Balzac's Coffee                         43 Hanna Avenue, Unit 123
# 286                        Tim Hortons                               171 East Liberty St
# 287                          Starbucks                   20 Innovation Drive, Building B       M6L Maple Leaf Park, North Park, Upwood Park          3
# 288                        Tim Hortons                            Meadowvale Town Centre
# 289                        Coffee Time                               1575 Lawrence Ave W
# 290             Timothy's World Coffee                                    Eglinton Ave W   M6M Del Ray, Keelesdale, Mount Dennis, Silver...         13
# 291                        Tim Hortons                                       895 Jane St                  M6N The Junction North, Runnymede         26
# 292                        Tim Hortons                 2571 St Clair Ave West, Unit # E1
# 293                        Tim Hortons                               3487 Dundas St West
# 294               Caboose Coffee House                            3333 Dundas St. WestÂ
# 295                          Hula Girl                                2473 Dundas St. W.                  M6P High Park, The Junction South         81
# 296                   Crema Coffee Co.                                 3079 Dundas St. W
# 297                          Starbucks                                  3077 Dundas St W
# 298                        Tim Hortons                               110 West Toronto St
# 299                        Tim Hortons                                1728 Bloor St West
# 300                        Tim Hortons                                  3157 Dundas St W
# 301          Reunion Island Coffee Bar                              385 Roncesvalles Ave                         M6R Parkdale, Roncesvalles         67
# 302                   Lit Espresso Bar                           221 Roncesvalles Avenue
# 303            Outpost Coffee Roasters                               1578 Bloor St. West
# 304                        Tim Hortons                              175 Roncesvalles Ave
# 305                          Starbucks                                  2201 Dundas St W
# 306               Wibke's Espresso Bar                                  2465 Bloor St. W                             M6S Runnymede, Swansea         54
# 307                          Starbucks                                     2210 Bloor St
# 308                     Lit Cafe + Bar
# 309                        Tim Hortons                                2485 Bloor St West
# 310             Timothy's World Coffee                                   2190 Bloor St W
# 311                        Tim Hortons                                       Willard ave
# 312             Timothy's World Coffee                                   2402 Bloor St W
# 313                        Tim Hortons                                2150 Bloor St West
# 314                The Coffee Bouquets                               7 Riverview Gardens
# 315                      Coffee Island                                    925 Bay street                                   M7A Queen's Park         74
# 316                     Jimmy's Coffee                               82 Gerrard Street W
# 317                      Hailed Coffee                                   44 Gerrard St W
# 318                      Coffee Public                                        800 Bay St
# 319                          Starbucks                                       761 Bay St.
# 320                        Tim Hortons                                70 Gerrard St West
# 321                   Starbucks (MaRS)                                    101 College St
# 322                          Starbucks                           585 University Ave,R-16
# 323                          Starbucks                                     485 Church St
# 324                        Tim Hortons                                     4567 Dixie Rd          M7R Canada Post Gateway Processing Centre         38
# 325                        Tim Hortons                                     5014 Dixie Rd
# 326                          Starbucks                                     5067 Dixie Rd
# 327                        Tim Hortons                                   4880 Tahoe Blvd
# 328                        Tim Hortons                                   1520 Aimco Blvd
# 329        Tango Palace Coffee Company                                   1156 Queen St E   M7Y Business Reply Mail Processing Centre 969...         22
# 330                          Starbucks                      1015 Lakeshore Blvd E,CRU #4
# 331                        Tim Hortons                          1681 Lakeshore Blvd East
# 332       Big Guy's Little Coffee Shop                             2861 Lakeshore Blvd W   M8V Humber Bay Shores, Mimico South, New Toronto         14
# 333                        Tim Hortons                                   435 Browns Line                         M8W Alderwood, Long Branch         17
# 334                          Starbucks                                   2940 Bloor St W   M8X The Kingsway, Montgomery Road, Old Mill N...         39
# 335                          Starbucks                                   3079 Bloor St W
# 336                          Starbucks                              4242 Dundas Street W
# 337                        Tim Hortons                                3071 Bloor St West
# 338                        Tim Hortons                                1084 Islington Ave   M8Z Kingsway Park South West, Mimico NW, The ...         41
# 339                        Tim Hortons                                1000 The Queensway
# 340                        Tim Hortons                                1025 The Queensway
# 341                        Tim Hortons                              555 Burnhamthorpe Rd   M9C Bloordale Gardens, Eringate, Markland Woo...          9
# 342                        Tim Hortons                            2013 Lawrence Ave West                                         M9N Weston          6
# 343             Tim Horton's / Wendy's                               2013 Lawrence Ave W
# 344                          Starbucks                                1564 Royal York Rd                                      M9P Westmount          5
# 345                      Country Style                                      1935 Kipling   M9R Kingsview Village, Martin Grove Gardens, ...         12
# 346                        Tim Hortons                               6220 Finch Ave West   M9V Albion Gardens, Beaumond Heights, Humberg...          8
# 347                        Tim Hortons                               116 Queens Plate Dr                                      M9W Northwest          0

# %% [markdown]
# <b>A list of businesses, by neighborhood (with Prosval and Terriscore)</b>

# %%
final2 = pd.read_csv('C:\\Users\HP\Desktop\COURSERA\IBM Data Science\CAPSTONE\BUSINESSES.csv', encoding="ISO-8859-1")

final2 = final2.fillna("")

print(final2.shape)
final2.head(100)
# Out:
# (4853, 6)
#    TERRISCORE                                      NEIGHBORHOOD                             BUSINESS                            ADDRESS                       CATEGORY  PROSVAL
# 0          18                                M1B Rouge, Malvern                   Images Salon & Spa                8130 Sheppard Ave E                            Spa        2
# 1                                                                                     Caribbean Wave                     875 Milner Ave           Caribbean Restaurant        1
# 2                                                                                            Wendy's               8129 Sheppard Avenue           Fast Food Restaurant        1
# 3                                                                                           Harvey's                     853 Milner Ave           Fast Food Restaurant        1
# 4                                                                                            Wendy's                                              Fast Food Restaurant        1
# 5                                                                                        Tim Hortons                  8129 Sheppard Ave                    Coffee Shop        0
# 6                                                                                Staples Morningside                  850 Milner Avenue  Paper / Office Supplies Store        1
# 7                                                                                         Lee Valley                   1275 Morningside                     Hobby Shop        2
# 8                                                                                 Tim Hortons / Esso           Morningside and sheppard                    Coffee Shop        0
# 9                                                                                  MMA World Academy   15 Grand Marshall Drive, Suite 2              Martial Arts Dojo        2
# 10                                                                                           Mr Jerk            1161 Morningside Avenue             African Restaurant        1
# 11                                                                          Charley's Exotic Cuisine             3-1158 Morningside Ave             Chinese Restaurant        1
# 12                                                                                 MR. GREEK Express                     855 Milner Ave               Greek Restaurant        1
# 13                                                                                Fusion Supermarket               1150 Morningside Ave        Fruit & Vegetable Store        2
# 14                                                                                          Fit4Less                     855 Milner Ave                            Gym        2
# 15                                                                                           Quiznos                     875 Milner Ave                 Sandwich Place        0
# 16          1        M1C Highland Creek, Rouge Hill, Port Union            Fratelli Village Pizzeria              384 Old Kingston Road             Italian Restaurant        1
# 17                                                                                  Shamrock Burgers              6070 Old Kingston Rd.                   Burger Joint        0
# 18                                                                                  Ted's Restaurant               404 Old Kingston Rd.                 Breakfast Spot        0
# 19                                                                             Colonel Danforth Park                                                        Playground        0
# 20         14             M1E Guildwood, Morningside, West Hill                          Chick-N-Joy                 4449 Kingston Road            Fried Chicken Joint        0
# 21                                                                                         Bulk Barn                   4525 Kingston Rd              Food & Drink Shop        0
# 22                                                                                              LCBO                  4525 Kingston Rd.                   Liquor Store        1
# 23                                                                   Swiss Chalet Rotisserie & Grill                   4410 Kingston Rd                    Pizza Place        0
# 24                                                                                     Booster Juice       4525 Kingston Road, Unit #H8                  Smoothie Shop        0
# 25                                                                                         Starbucks                255 Morningside Ave                    Coffee Shop        0
# 26                                                                                         Dollarama  4525 Kingston Rd,Morningside Mall                 Discount Store        1
# 27                                                                                    The Beer Store            4479 Kingston Rd Unit 1                     Beer Store        2
# 28                                                                                Shoppers Drug Mart                255 Morningside Ave                       Pharmacy        2
# 29                                                                                        McDonald's                   4434 Kingston Rd           Fast Food Restaurant        1
# 30                                                                                   TD Canada Trust                   4515 Kingston Rd                           Bank        1
# 31                                                                                               KFC             245 Morningside Avenue           Fast Food Restaurant        1
# 32                                                                                            Subway                   4545 Kingston Rd                 Sandwich Place        0
# 33                                                                                         Pizza Hut                259 Morningside Ave                    Pizza Place        0
# 34                                                                            Taste Of Greek Cuisine                                                  Greek Restaurant        1
# 35                                                                                    Shoeless Joe's                245 Morningside Ave                     Sports Bar        0
# 36                                                                                       Pizza Pizza       4447 Kingston Road, Unit 7-8                    Pizza Place        0
# 37                                                                                Lick's Homeburgers                  4543 Kingston Rd.                   Burger Joint        0
# 38                                                                                       Tim Hortons                   4479 Kingston Rd                    Coffee Shop        0
# 39                                                                                       Food Basics             255 Morningside Avenue                    Supermarket        2
# 40                                                                                   Kingston Square                                                             Plaza        0
# 41                                                               Danny's Pub & International Cuisine               151 Morningside Ave.                     Restaurant        1
# 42                                                                                   M&M Food Market       4525 Kingston Road, Unit H11                  Grocery Store        0
# 43                                                                                         Pita Land                   4545 Kingston Rd               Greek Restaurant        1
# 44          6                                        M1G Woburn                            Starbucks                     300 Borough Dr                    Coffee Shop        0
# 45                                                                                       Lucky Hakka         3774 Lawrence Avenue East,             Chinese Restaurant        1
# 46                                                                                    Densgrove Park                        Scarborough                           Park        0
# 47                                                                    Guardian - Orton Park Pharmacy           136 Orton Park Rd,Unit 4                       Pharmacy        2
# 48                                                                                     Country Style                  136 Orton Park Rd                    Coffee Shop        0
# 49                                                                                      Aunty Mary's               3770 Lawrence Ave. E           Fast Food Restaurant        1
# 50                                                                                     Bombay Palace                   795 Markham Road              Indian Restaurant        1
# 51                                                                                              Bell       300 Borough Dr., Lower Level              Electronics Store        1
# 52         20                                     M1H Cedarbrae                  Federick Restaurant                  1920 Ellesmere Rd               Hakka Restaurant        1
# 53                                                                                   CANBE Foods Inc                 1760 Ellesmere Rd.              Indian Restaurant        1
# 54                                                                          Drupati's Roti & Doubles                  1085 Bellamy Rd N           Caribbean Restaurant        1
# 55                                                                  The Real McCoy Burgers And Pizza                  1021 Markham Road                   Burger Joint        0
# 56                                                                                       Tim Hortons                    1150 Markham Rd                    Coffee Shop        0
# 57                                                                                       Thai One On                1911 Ellesmere Road                Thai Restaurant        1
# 58                                                                                      Hakka Legend                2058 Ellesmere Road             Chinese Restaurant        1
# 59                                                                                     La Sani Grill          2058 Ellesmere Rd, Unit 3              Indian Restaurant        1
# 60                                                                                    Long & McQuade                   1133 Markham Rd.                    Music Store        2
# 61                                                                                Shoppers Drug Mart                    1235 Mccowan Rd                       Pharmacy        2
# 62                                                                      Centennial Recreation Centre                  1967 Ellesmere Rd             Athletics & Sports        0
# 63                                                                                   TD Canada Trust                  1900 Ellesmere Rd                           Bank        1
# 64                                                                                        B&A Bakery                 1820 Ellesmere Rd.                         Bakery        0
# 65                                                                              AllStar Wings & Ribs                    1245 McCowan Rd                    Wings Joint        1
# 66                                                                         Popeyes Louisiana Kitchen                  2030 Ellesmere Rd            Fried Chicken Joint        0
# 67                                                                                    Mitra Hot Yoga                   705 Progress Ave                    Yoga Studio        1
# 68                                                                                       Tim Hortons                    60 Tuxedo Court                    Coffee Shop        0
# 69                                                                                        The Avenue          1085 Bellamy Rd. N Unit 4                         Lounge        0
# 70                                                                                          FreshCo.                   1255 McCowan Rd.                  Grocery Store        0
# 71                                                                                    Coffee Culture                  2060 Ellesmere Rd                    Coffee Shop        0
# 72                                                                                        McDonald's                    1280 Markham Rd           Fast Food Restaurant        1
# 73                                                                                  So into Cupcakes                2060 Ellesmere Road                         Bakery        0
# 74                                                                               Penske Truck Rental                   80 Production Dr            Rental Car Location        1
# 75                                                                                 Rexall PharmaPlus                            Markham                       Pharmacy        2
# 76                                                                           Bus Stop: 102, 38, & 95                Markham & Ellesmere                       Bus Line        0
# 77                                                                                             Mac's                  1021 Markham Road                       Pharmacy        2
# 78                                                                     East Star Asphalt Maintenance                   727 Progress Ave                   Home Service        0
# 79                                                                                        Marchant's                849 Progress Avenue            Sporting Goods Shop        1
# 80                                                                              Quality Bread Bakery                    1221 Markham Rd                         Bakery        0
# 81                                                                                     Fabian's Cafe                    876 Markham Rd.                         Bakery        0
# 82          7                           M1J Scarborough Village                        Diamond Pizza                      Danforth Road                    Pizza Place        0
# 83                                                                            Dairy Queen Restaurant                2916 Eglinton Ave E           Fast Food Restaurant        1
# 84                                                                                       Tim Hortons             2874 Eglinton Ave East                    Coffee Shop        0
# 85                                                                       DQ Grill & Chill Restaurant                2916 Eglinton Ave E           Fast Food Restaurant        1
# 86                                                                                            Subway               2911 Eglinton Ave. E                 Sandwich Place        0
# 87                                                                   Swiss Chalet Rotisserie & Grill                2990 Eglinton Ave E                     Restaurant        1
# 88                                                                           Mac's Convenience Store             2900 Eglinton Ave East              Convenience Store        0
# 89                                                                               Eglinton GO Station            2995 Eglinton Ave. East                  Train Station        0
# 90                                                                      Nakamori Japanese Restaurant                2803 Eglinton Ave E            Japanese Restaurant        1
# 91                                                                                        McDonald's                2870 Eglinton Ave E           Fast Food Restaurant        1
# 92                                                                              All Star Interactive                2791 Eglinton Ave E                  Bowling Alley        2
# 93         12   M1K East Birchmount Park, Ionview, Kennedy Park                          Tim Hortons             2500 Eglinton Ave East                    Coffee Shop        0
# 94                                                                                         Dollarama             2480 Eglinton Avenue E                 Discount Store        1
# 95                                                                                         Chung Moi                2412 Eglinton Ave E             Chinese Restaurant        1
# 96                                                                                       Giant Tiger                   682 Kennedy Road               Department Store        1
# 97                                                                                            Subway               2395 Eglinton Ave. E                 Sandwich Place        0
# 98                                                                 T-Bones Sizzling Steaks & Burgers             2540 Eglinton Ave East                   Burger Joint        0
# 99                                                                                       Tim Hortons                 678-682 Kennedy Rd                    Coffee Shop        0

# %% [markdown]
# <b>A ranking of all neighborhoods based on their Terriscore</b>

# %%
final3 = pd.read_csv('C:\\Users\HP\Desktop\COURSERA\IBM Data Science\CAPSTONE\RANKINGS.csv', encoding="ISO-8859-1")

final3 = final3.fillna("")

print(final3.shape)
final3
# Out:
# (102, 3)
#                                           NEIGHBORHOOD  TERRISCORE  BUSINESSES
# 0        M5T Chinatown, Grange Park, Kensington Market          92         100
# 1     M6K Brockton, Exhibition Place, Parkdale Village          90         100
# 2                   M5S Harbord, University of Toronto          89         100
# 3                         M6J Little Portugal, Trinity          88         100
# 4                         M5H Adelaide, King, Richmond          87         100
# 5                                     M4J East Toronto          87          99
# 6                                       M4S Davisville          84         100
# 7              M5R The Annex, North Midtown, Yorkville          84         100
# 8                                  M4M Studio District          83         100
# 9                    M6P High Park, The Junction South          81         100
# 10                                M2N Willowdale South          80         100
# 11                                        M6G Christie          79         100
# 12                                M4P Davisville North          78         100
# 13                       M5A Harbourfront, Regent Park          78         100
# 14                            M4Y Church and Wellesley          77         100
# 15                              M5G Central Bay Street          77         100
# 16                        M5B Ryerson, Garden District          76         100
# 17          M5X First Canadian Place, Underground city          76         100
# 18                    M4K The Danforth West, Riverdale          74         100
# 19                                    M7A Queen's Park          74         100
# 20    M5J Harbourfront East, Toronto Islands, Union...          73         100
# 21                                  M5C St. James Town          71         100
# 22        M5K Design Exchange, Toronto Dominion Centre          71         100
# 23                  M5L Commerce Court, Victoria Hotel          67         100
# 24                          M6R Parkdale, Roncesvalles          67         100
# 25                    M6H Dovercourt Village, Dufferin          64          65
# 26                 M5W Stn A PO Boxes 25 The Esplanade          62         100
# 27                                     M5E Berczy Park          61         100
# 28                  M4L The Beaches West, India Bazaar          55          79
# 29    M4V Deer Park, Forest Hill SE, Rathnelly, Sou...          55          75
# 30                              M6S Runnymede, Swansea          54          74
# 31                M6A Lawrence Heights, Lawrence Manor          48          53
# 32                                         M4G Leaside          46          60
# 33                                     M4E The Beaches          45          78
# 34                     M4T Moore Park, Summerhill East          42          62
# 35    M8Z Kingsway Park South West, Mimico NW, The ...          41          54
# 36    M1P Dorset Park, Scarborough Town Centre, Wex...          40          46
# 37                M3C Flemingdon Park, Don Mills South          40          39
# 38    M8X The Kingsway, Montgomery Road, Old Mill N...          39          46
# 39           M7R Canada Post Gateway Processing Centre          38          50
# 40                                       M1S Agincourt          37          47
# 41             M5P Forest Hill North, Forest Hill West          36          46
# 42                     M4X Cabbagetown, St. James Town          36          42
# 43                    M2J Fairview, Henry Farm, Oriole          35          43
# 44                              M4R North Toronto West          33          41
# 45               M5M Bedford Park, Lawrence Manor East          33          41
# 46                                M4H Thorncliffe Park          32          45
# 47                                       M6B Glencairn          29          39
# 48                                        M5N Roselawn          27          25
# 49                   M6N The Junction North, Runnymede          26          41
# 50                             M3N Downsview Northwest          24          31
# 51                         M2M Newtonbrook, Willowdale          24          30
# 52                                 M3B Don Mills North          23          33
# 53    M7Y Business Reply Mail Processing Centre 969...          22          47
# 54    M1V Agincourt North, L'Amoreaux East, Millike...          21          30
# 55                                       M1H Cedarbrae          20          30
# 56         M1T Clarks Corners, Sullivan, Tam O'Shanter          20          30
# 57                             M6E Caledonia-Fairbanks          19          25
# 58                                M4C Woodbine Heights          18          31
# 59                                       M3A Parkwoods          18          29
# 60                                  M1B Rouge, Malvern          18          16
# 61                          M8W Alderwood, Long Branch          17          26
# 62                               M1R Maryvale, Wexford          16          25
# 63                 M4B Woodbine Gardens, Parkview Hill          15          21
# 64               M1E Guildwood, Morningside, West Hill          14          24
# 65                   M1W L'Amoreaux West, Steeles West          14          24
# 66                 M3J Northwood Park, York University          14          23
# 67    M8V Humber Bay Shores, Mimico South, New Toronto          14          20
# 68    M6M Del Ray, Keelesdale, Mount Dennis, Silver...          13          19
# 69    M3H Bathurst Manor, Downsview North, Wilson H...          12          25
# 70     M1K East Birchmount Park, Ionview, Kennedy Park          12          23
# 71                               M2H Hillcrest Village          12          21
# 72                     M3K CFB Toronto, Downsview East          12          16
# 73    M9R Kingsview Village, Martin Grove Gardens, ...          12          14
# 74                 M1L Clairlea, Golden Mile, Oakridge          11          29
# 75                              M6C Humewood-Cedarvale          11          28
# 76                     M1N Birch Cliff, Cliffside West          11          14
# 77    M9B Cloverdale, Islington, Martin Grove, Prin...          10          15
# 78                                M9A Islington Avenue          10          13
# 79                                 M2K Bayview Village           9          14
# 80    M9C Bloordale Gardens, Eringate, Markland Woo...           9          13
# 81                                        M4W Rosedale           8          22
# 82    M9V Albion Gardens, Beaumond Heights, Humberg...           8          16
# 83                                 M2P York Mills West           7          16
# 84    M5V CN Tower, Bathurst Quay, Island airport, ...           7          16
# 85                                M4A Victoria Village           7          14
# 86                             M1J Scarborough Village           7          11
# 87                                 M2R Willowdale West           7          11
# 88                                   M9L Humber Summit           7          10
# 89                                   M4N Lawrence Park           7           9
# 90                                          M9N Weston           6          16
# 91                                  M3L Downsview West           6          10
# 92                                          M1G Woburn           6           8
# 93    M1M Cliffcrest, Cliffside, Scarborough Villag...           5          13
# 94                                       M9P Westmount           5          12
# 95                               M3M Downsview Central           5           5
# 96        M6L Maple Leaf Park, North Park, Upwood Park           3          12
# 97    M8Y Humber Bay, King's Mill Park, Kingsway Pa...           3           7
# 98                                M9M Emery, Humberlea           2           7
# 99          M1C Highland Creek, Rouge Hill, Port Union           1           4
# 100                       M2L Silver Hills, York Mills           0           4
# 101                                      M9W Northwest           0           1

# %% [markdown]
# # DISCUSSION

# %% [markdown]
# If you look at the final deliverable, the ranking of neighborhoods by Terrascore, you see that there are a number of neighborhoods with high scores. The median Terriscore from 102 neighborhoods is 24, and 30 neighborhoods scored 50 or higher. Realistically, a sales agent should be able to sell out the available display advertising space in a coffee shop by presenting to no more than a couple dozen interested businesses. Terriscore attempts to create a quality-weighted metric that should equate to a count of probable coffee shop display advertising buyers. By this standard, at least half of the neighborhoods in Toronto should be viable sales territories. On a simple unweighted counting basis, 67 neighborhoods returned at least 24 businesses to approach.
#
# The final deliverable also offers a potential opportunity to reconsider the additive index approach. Consider the top-ranked neighborhood, M5T Chinatown, Grange Park, Kensington Market. It returns the max of 100 businesses, but achives a Terriscore of 92. That 92% ratio may demand being built into a quality metric. The lowest Terriscore among neighborhoods that provided 100 businesses was 61 (M5E Berczy Park), a 61% ratio. The next lower Terriscore on the list is 55 (M4L The Beaches West, India Bazaar), but it is based on only 79 businesses, a 69.6% ratio. Which is the "better" score? It may be the case that above a certain quantity threshhold a Terriscore ratio should prevail when allocating sales agents into territories.
#
# We were limited to returning no more than 100 results for a given search, which covered a radius of 1000m around each neighborhood's lat/lng focal point. That search criteria leads to roughly 1,500 duplicates (business addresses that appear in more than one neighborhood area). It is not necessarily the case that duplicates are a problem. There is no reason to presume that a given business will not advertise within more than one coffee shop in its business area. A sales agent may well find themselves calling on a business that has already committed to another coffee shop, but this does not mean the call is not worth making. Advertisers advertise, and the worst case from any sales call is a "no."

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# The primary takeaway from this project is that the quantity of data that was <b>not</b> available is large and potentially more useful than the data collected. For example, FourSquare business types did not include <b>professional people</b> (medical, legal, financial, real estate, etc.) who are typically asssigned Prosval scores of 2 and who traditionally purchase local advertising in all forms. There are <b>only 56 banks</b> in a data set that includes nearly 3,500 businesses. Small independent banks have been reliable buyers of local display advertising in the past. Are there really only 56 banks in Toronto, or is the data incomplete? Other examples of enthusiastic buyers of local display advertising that are effectively missing from the data include <b>automotive related businesses</b> (repair, dealerships, rental, etc contribute less than 10 data points), <b>end of life services,</b> and <b>building contractors</b> (plumber, electrical, HVAC, carpentry, etc.).
#
# TV Fanfare Publications, the company mentioned at the beginning of this report, allowed its independent subcontractor sales agents great latitude in devising procedures for selling display advertising to appear in supermarkets. The process worked as follows, more or less.
#
# •	Go to the sales territory and collect all forms of print advertising available<br>
# •	Contact advertisers, by business type, by size/frequency of advertisement, as you prefer<br>
# •	Sell out the display advertising space available in the supermarket and move on<br>
#
# This is the model that Cafn8 will attempt to reproduce, more or less. Understanding where this project falls in the context of that model, it would appear that another iteration of Data Science should probably be pursued to build on our limited results.
#
# Here is the issue Cafn8 must consider: <b>Will additional effort lead to different and better results?</b> ... <B>ROBUST?</B>
#
# "Robust" is the word for that notion. Additional data to be processed into information comes at a cost (acquisition cost, processing cost, intellectual resource commitment). Based on our results, it would appear obvious that large amounts of additional data <b>are worth accumulating and processing.</b> Data on the unrepresented and underrepresented businesses above is a must to collect and assess. Whether adding this data to our project would actually change the rankings is uncertain, but it would definitely add to the number of potential customers and perhaps offer a reason to be more aggressive about pricing, or some other aspect of the structure of the coffee shop display advertising deal being offered. It would also raise the stakes for making optimal assignments of the most effective sales agents to the most lucrative territories.
#
# Wherever possible, making maximum use of low cost proxy data that is robust offers enormous returns on investment in Data Science. In the case of this project, we are confident that valuable sales territory information has been created by producing Terriscores despite having incomplete data. Future efforts to improve on deliverables will be worth pursuing, but are unlikely to contradict the primary result. Adding new business categories or adjusting Prosval for business types may alter the rankings somewhat, but it appears unlikely that the rankings would flip under any circumstances. There should not be any systematic effect that would move a given cluster of neighborhoods very far from its current position on the ranked list in future Data Science projects.
#
# For that reason, Cafn8 should be pleased with this report and find value in makinng use of it to make decisions about sales territories in Toronto.
